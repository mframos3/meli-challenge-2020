# %% [markdown]
# # Setup

# %%
import torch
import numpy as np

# %%
from tqdm.notebook import tqdm
import os

# %%
class PointWiseFeedForward(torch.nn.Module):
    def __init__(self, hidden_units, dropout_rate):

        super(PointWiseFeedForward, self).__init__()

        self.conv1 = torch.nn.Conv1d(hidden_units, hidden_units, kernel_size=1)
        self.dropout1 = torch.nn.Dropout(p=dropout_rate)
        self.relu = torch.nn.ReLU()
        self.conv2 = torch.nn.Conv1d(hidden_units, hidden_units, kernel_size=1)
        self.dropout2 = torch.nn.Dropout(p=dropout_rate)

    def forward(self, inputs):
        outputs = self.dropout2(self.conv2(self.relu(self.dropout1(self.conv1(inputs.transpose(-1, -2))))))
        outputs = outputs.transpose(-1, -2) # as Conv1D requires (N, C, Length)
        outputs += inputs
        return outputs

# %%
class SASRec(torch.nn.Module):
    def __init__(self, user_num, item_num, args):
        super(SASRec, self).__init__()

        self.user_num = user_num
        self.item_num = item_num
        self.dev = args.device

        # TODO: loss += args.l2_emb for regularizing embedding vectors during training
        # https://stackoverflow.com/questions/42704283/adding-l1-l2-regularization-in-pytorch
        self.item_emb = torch.nn.Embedding(self.item_num+1, args.hidden_units, padding_idx=0)
        self.pos_emb = torch.nn.Embedding(args.maxlen, args.hidden_units) # TO IMPROVE
        self.emb_dropout = torch.nn.Dropout(p=args.dropout_rate)

        self.attention_layernorms = torch.nn.ModuleList() # to be Q for self-attention
        self.attention_layers = torch.nn.ModuleList()
        self.forward_layernorms = torch.nn.ModuleList()
        self.forward_layers = torch.nn.ModuleList()

        self.last_layernorm = torch.nn.LayerNorm(args.hidden_units, eps=1e-8)

        for _ in range(args.num_blocks):
            new_attn_layernorm = torch.nn.LayerNorm(args.hidden_units, eps=1e-8)
            self.attention_layernorms.append(new_attn_layernorm)

            new_attn_layer =  torch.nn.MultiheadAttention(args.hidden_units,
                                                            args.num_heads,
                                                            args.dropout_rate)
            self.attention_layers.append(new_attn_layer)

            new_fwd_layernorm = torch.nn.LayerNorm(args.hidden_units, eps=1e-8)
            self.forward_layernorms.append(new_fwd_layernorm)

            new_fwd_layer = PointWiseFeedForward(args.hidden_units, args.dropout_rate)
            self.forward_layers.append(new_fwd_layer)

            # self.pos_sigmoid = torch.nn.Sigmoid()
            # self.neg_sigmoid = torch.nn.Sigmoid()

    def log2feats(self, log_seqs):
        seqs = self.item_emb(torch.LongTensor(log_seqs).to(self.dev))
        seqs *= self.item_emb.embedding_dim ** 0.5
        positions = np.tile(np.array(range(log_seqs.shape[1])), [log_seqs.shape[0], 1])
        seqs += self.pos_emb(torch.LongTensor(positions).to(self.dev))
        seqs = self.emb_dropout(seqs)

        timeline_mask = torch.BoolTensor(log_seqs == 0).to(self.dev)
        seqs *= ~timeline_mask.unsqueeze(-1) # broadcast in last dim

        tl = seqs.shape[1] # time dim len for enforce causality
        attention_mask = ~torch.tril(torch.ones((tl, tl), dtype=torch.bool, device=self.dev))

        for i in range(len(self.attention_layers)):
            seqs = torch.transpose(seqs, 0, 1)
            Q = self.attention_layernorms[i](seqs)
            mha_outputs, _ = self.attention_layers[i](Q, seqs, seqs, 
                                            attn_mask=attention_mask)
                                            # key_padding_mask=timeline_mask
                                            # need_weights=False) this arg do not work?
            seqs = Q + mha_outputs
            seqs = torch.transpose(seqs, 0, 1)

            seqs = self.forward_layernorms[i](seqs)
            seqs = self.forward_layers[i](seqs)
            seqs *=  ~timeline_mask.unsqueeze(-1)

        log_feats = self.last_layernorm(seqs) # (U, T, C) -> (U, -1, C)

        return log_feats

    def forward(self, user_ids, log_seqs, pos_seqs, neg_seqs): # for training        
        log_feats = self.log2feats(log_seqs) # user_ids hasn't been used yet

        pos_embs = self.item_emb(torch.LongTensor(pos_seqs).to(self.dev))
        neg_embs = self.item_emb(torch.LongTensor(neg_seqs).to(self.dev))

        pos_logits = (log_feats * pos_embs).sum(dim=-1)
        neg_logits = (log_feats * neg_embs).sum(dim=-1)

        # pos_pred = self.pos_sigmoid(pos_logits)
        # neg_pred = self.neg_sigmoid(neg_logits)

        return pos_logits, neg_logits # pos_pred, neg_pred

    def predict(self, user_ids, log_seqs, item_indices): # for inference
        log_feats = self.log2feats(log_seqs) # user_ids hasn't been used yet

        final_feat = log_feats[:, -1, :] # only use last QKV classifier, a waste

        item_embs = self.item_emb(torch.LongTensor(item_indices).to(self.dev)) # (U, I, C)

        logits = item_embs.matmul(final_feat.unsqueeze(-1)).squeeze(-1)

        # preds = self.pos_sigmoid(logits) # rank same item list for different users

        return logits # preds # (U, I)

# %%
import sys
import copy
import torch
import random
import numpy as np
from collections import defaultdict
from multiprocessing import Process, Queue

# sampler for batch generation
def random_neq(l, r, s):
    t = np.random.randint(l, r)
    while t in s:
        t = np.random.randint(l, r)
    return t


def sample_function(user_train, usernum, itemnum, batch_size, maxlen, result_queue, SEED):
    def sample():

        user = np.random.randint(1, usernum + 1)
        while len(user_train[user]) <= 1: user = np.random.randint(1, usernum + 1)

        seq = np.zeros([maxlen], dtype=np.int32)
        pos = np.zeros([maxlen], dtype=np.int32)
        neg = np.zeros([maxlen], dtype=np.int32)
        nxt = user_train[user][-1]
        idx = maxlen - 1

        ts = set(user_train[user])
        for i in reversed(user_train[user][:-1]):
            seq[idx] = i
            pos[idx] = nxt
            if nxt != 0: neg[idx] = random_neq(1, itemnum + 1, ts)
            nxt = i
            idx -= 1
            if idx == -1: break

        return (user, seq, pos, neg)

    np.random.seed(SEED)
    while True:
        one_batch = []
        for i in range(batch_size):
            one_batch.append(sample())

        result_queue.put(zip(*one_batch))


class WarpSampler(object):
    def __init__(self, User, usernum, itemnum, batch_size=64, maxlen=10, n_workers=1):
        self.result_queue = Queue(maxsize=n_workers * 10)
        self.processors = []
        for i in range(n_workers):
            self.processors.append(
                Process(target=sample_function, args=(User,
                                                      usernum,
                                                      itemnum,
                                                      batch_size,
                                                      maxlen,
                                                      self.result_queue,
                                                      np.random.randint(2e9)
                                                      )))
            self.processors[-1].daemon = True
            self.processors[-1].start()

    def next_batch(self):
        return self.result_queue.get()

    def close(self):
        for p in self.processors:
            p.terminate()
            p.join()


# train/val/test data generation
def data_partition(fname, type_dataset='train'):
    usernum = 0
    itemnum = 0
    User = defaultdict(list)
    user_train = {}
    user_valid = {}
    user_test = {}
    # assume user/item index starting from 1
    f = open(fname, 'r')
    for line in f:
        u, i = line.rstrip().split(' ')
        u = int(u)
        i = int(i)
        usernum = max(u, usernum)
        itemnum = max(i, itemnum)
        User[u].append(i)

    for user in User:
      if type_dataset=='train':
        nfeedback = len(User[user])
        if nfeedback < 3:
            user_train[user] = User[user]
            user_valid[user] = []
            user_test[user] = []
        else:
            user_train[user] = User[user][:-2]
            user_valid[user] = []
            user_valid[user].append(User[user][-2])
            user_test[user] = []
            user_test[user].append(User[user][-1])
      elif type_dataset=='final_train':
        user_train[user] = User[user]
      else:  
        user_test[user] = User[user]
    return [user_train, user_valid, user_test, usernum, itemnum]

# TODO: merge evaluate functions for test and val set
# evaluate on test set
def predict(model, dataset, args, itemnum_train, output_file, index_dict, reindex_dict=None, possible_items=None):
    f = open(output_file, 'w')
    [train, valid, test, usernum, itemnum] = copy.deepcopy(dataset)
    users = range(1, usernum + 1)
    
    # Ahora hay que pasar los id de los items para predecir. 
    # Como estamos en produccion, les pasamos simplemente todos los id
    users_with_problems = []
    if not possible_items:   
      item_idx = [x for x in range(1, itemnum_train + 1)]
    for u in tqdm(users):
      seq = np.zeros([args.maxlen], dtype=np.int32)
      idx = args.maxlen - 1


      # Ahora se agregan todos los de train a la secuencia
      for i in reversed(test[u]):
        seq[idx] = i
        idx -= 1
        if idx == -1: break

      if possible_items:
        #item_idx = [reindex_dict[x] if reindex_dict[x] != -1 else 1 for x in possible_items[u]]
        item_idx = []
        for x in possible_items[u-1]:
          item = reindex_dict[x]
          if item == -1:
            item = 1
            print(f'Item {x} no esta en reindex')
            users_with_problems.append(u)
          else:
            item_idx.append(item)
      try:
        predictions = model.predict(*[np.array(l) for l in [[u], [seq], item_idx]])
        top10 = torch.topk(predictions[0], 10)
        indices = top10.indices.tolist()
      except:
        print(item_idx)
        print(predictions)
        print(top10)
        print(indices)
        break

      

      f.write(",".join((str(index_dict[item_idx[x]]) for x in indices)) + '\n')

      # Ya tenemos las 10 predicciones para el usuario. Ahora la escribimos en el output file

    f.close()
    return users_with_problems
    
def evaluate(model, dataset, args):
    [train, valid, test, usernum, itemnum] = copy.deepcopy(dataset)

    NDCG = 0.0
    HT = 0.0
    valid_user = 0.0

    if usernum>10000:
        users = random.sample(range(1, usernum + 1), 10000)
    else:
        users = range(1, usernum + 1)
    for u in users:

        if len(train[u]) < 1 or len(test[u]) < 1: continue

        seq = np.zeros([args.maxlen], dtype=np.int32)
        idx = args.maxlen - 1
        seq[idx] = valid[u][0]
        idx -= 1
        for i in reversed(train[u]):
            seq[idx] = i
            idx -= 1
            if idx == -1: break
        rated = set(train[u])
        rated.add(0)
        item_idx = [test[u][0]]
        for _ in range(100):
            t = np.random.randint(1, itemnum + 1)
            while t in rated: t = np.random.randint(1, itemnum + 1)
            item_idx.append(t)

        predictions = -model.predict(*[np.array(l) for l in [[u], [seq], item_idx]])
        predictions = predictions[0] # - for 1st argsort DESC

        rank = predictions.argsort().argsort()[0].item()

        valid_user += 1

        if rank < 10:
            NDCG += 1 / np.log2(rank + 2)
            HT += 1
        if valid_user % 100 == 0:
            print('.', end="")
            sys.stdout.flush()

    return NDCG / valid_user, HT / valid_user


# evaluate on val set
def evaluate_valid(model, dataset, args):
    [train, valid, test, usernum, itemnum] = copy.deepcopy(dataset)

    NDCG = 0.0
    valid_user = 0.0
    HT = 0.0
    if usernum>10000:
        users = random.sample(range(1, usernum + 1), 10000)
    else:
        users = range(1, usernum + 1)
    for u in users:
        if len(train[u]) < 1 or len(valid[u]) < 1: continue

        seq = np.zeros([args.maxlen], dtype=np.int32)
        idx = args.maxlen - 1
        for i in reversed(train[u]):
            seq[idx] = i
            idx -= 1
            if idx == -1: break

        rated = set(train[u])
        rated.add(0)
        item_idx = [valid[u][0]]
        for _ in range(100):
            t = np.random.randint(1, itemnum + 1)
            while t in rated: t = np.random.randint(1, itemnum + 1)
            item_idx.append(t)

        predictions = -model.predict(*[np.array(l) for l in [[u], [seq], item_idx]])
        predictions = predictions[0]

        rank = predictions.argsort().argsort()[0].item()

        valid_user += 1

        if rank < 10:
            NDCG += 1 / np.log2(rank + 2)
            HT += 1
        if valid_user % 100 == 0:
            print('.', end="")
            sys.stdout.flush()

    return NDCG / valid_user, HT / valid_user

# %%
class Args:
  def __init__(self, dataset, train_dir, batch_size=128, lr=0.001, maxlen=30, hidden_units=64, num_blocks=3, num_epochs=50, num_heads=1, dropout_rate=0.5, l2_emb=0.0, device='cuda', inference_only=False, state_dict_path=None):
    self.dataset = dataset
    self.train_dir = train_dir
    self.batch_size = batch_size
    self.lr = lr
    self.maxlen = maxlen
    self.hidden_units = hidden_units
    self.num_blocks = num_blocks
    self.num_epochs = num_epochs
    self.num_heads = num_heads
    self.dropout_rate = dropout_rate
    self.l2_emb = l2_emb
    self.device = device
    self.inference_only = inference_only
    self.state_dict_path = state_dict_path

# %%
args = Args('/content/drive/Shareddrives/RecSys/Datasets/mercadolibre.txt', 'data')

# %%
dataset = data_partition(args.dataset, 'final_train')
[user_train, user_valid, user_test, usernum, itemnum] = dataset
num_batch = len(user_train) // args.batch_size # tail? + ((len(user_train) % args.batch_size) != 0)
print(f'Number of batches: {num_batch}')
cc = 0.0
for u in user_train:
    cc += len(user_train[u])
print('average sequence length: %.2f' % (cc / len(user_train)))
# Out:
# Number of batches: 4161
# average sequence length: 16.62

# %%
model = SASRec(usernum, itemnum, args).to(args.device)  # no ReLU activation in original SASRec implementation?

# %%
sampler = WarpSampler(user_train, usernum, itemnum, batch_size=args.batch_size, maxlen=args.maxlen, n_workers=3)
 # no ReLU activation in original SASRec implementation?

for name, param in model.named_parameters():
    try:
        torch.nn.init.xavier_uniform_(param.data)
    except:
        pass # just ignore those failed init layers

# this fails embedding init 'Embedding' object has no attribute 'dim'
# model.apply(torch.nn.init.xavier_uniform_)

model.train() # enable model training

epoch_start_idx = 1
if args.state_dict_path is not None:
    try:
        model.load_state_dict(torch.load(args.state_dict_path, map_location=torch.device(args.device)))
        tail = args.state_dict_path[args.state_dict_path.find('epoch=') + 6:]
        epoch_start_idx = int(tail[:tail.find('.')]) + 1
    except: # in case your pytorch version is not 1.6 etc., pls debug by pdb if load weights failed
        print('failed loading state_dicts, pls check file path: ', end="")
        print(args.state_dict_path)
        print('pdb enabled for your quick check, pls type exit() if you do not need it')
        import pdb; pdb.set_trace()
        

if args.inference_only:
    model.eval()
    t_test = evaluate(model, dataset, args)
    print('test (NDCG@10: %.4f, HR@10: %.4f)' % (t_test[0], t_test[1]))

# ce_criterion = torch.nn.CrossEntropyLoss()
# https://github.com/NVIDIA/pix2pixHD/issues/9 how could an old bug appear again...
bce_criterion = torch.nn.BCEWithLogitsLoss() # torch.nn.BCELoss()
adam_optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, betas=(0.9, 0.98))

# %%
import time

#f = open(os.path.join(args.dataset + '_' + args.train_dir, 'log.txt'), 'w')
T = 0.0
t0 = time.time()

for epoch in range(epoch_start_idx, args.num_epochs + 1):
    if args.inference_only: break # just to decrease identition
    for step in range(num_batch): # tqdm(range(num_batch), total=num_batch, ncols=70, leave=False, unit='b'):
        u, seq, pos, neg = sampler.next_batch() # tuples to ndarray
        u, seq, pos, neg = np.array(u), np.array(seq), np.array(pos), np.array(neg)
        pos_logits, neg_logits = model(u, seq, pos, neg)
        pos_labels, neg_labels = torch.ones(pos_logits.shape, device=args.device), torch.zeros(neg_logits.shape, device=args.device)
        # print("\neye ball check raw_logits:"); print(pos_logits); print(neg_logits) # check pos_logits > 0, neg_logits < 0
        adam_optimizer.zero_grad()
        indices = np.where(pos != 0)
        loss = bce_criterion(pos_logits[indices], pos_labels[indices])
        loss += bce_criterion(neg_logits[indices], neg_labels[indices])
        for param in model.item_emb.parameters(): loss += args.l2_emb * torch.norm(param)
        loss.backward()
        adam_optimizer.step()
        if step % 100 == 0:
          print("loss in epoch {} iteration {}: {}".format(epoch, step, loss.item())) # expected 0.4~0.6 after init few epochs


    if epoch % 200 == 0: # Aqui lo cambie a 200 para que no haya evaluacion
        model.eval()
        t1 = time.time() - t0
        T += t1
        print('Evaluating', end='')
        t_test = evaluate(model, dataset, args)
        t_valid = evaluate_valid(model, dataset, args)
        print('epoch:%d, time: %f(s), valid (NDCG@10: %.4f, HR@10: %.4f), test (NDCG@10: %.4f, HR@10: %.4f)'
                % (epoch, T, t_valid[0], t_valid[1], t_test[0], t_test[1]))

        #f.write(str(t_valid) + ' ' + str(t_test) + '\n')
        #f.flush()
        t0 = time.time()
        model.train()

    if epoch == args.num_epochs:
        folder = '/content/drive/Shareddrives/RecSys/MeLi/checkpoints'
        fname = 'SASRec.epoch={}.lr={}.layer={}.head={}.hidden={}.maxlen={}.pth'
        fname = fname.format(args.num_epochs, args.lr, args.num_blocks, args.num_heads, args.hidden_units, args.maxlen)
        torch.save(model.state_dict(), os.path.join(folder, fname))

#f.close()
sampler.close()
print("Done")
# Out:
# loss in epoch 1 iteration 0: 1.3861044645309448
# loss in epoch 1 iteration 100: 1.3078761100769043
# loss in epoch 1 iteration 200: 1.2382941246032715
# loss in epoch 1 iteration 300: 1.2038002014160156
# loss in epoch 1 iteration 400: 1.178877353668213
# loss in epoch 1 iteration 500: 1.1447324752807617
# loss in epoch 1 iteration 600: 1.151376485824585
# loss in epoch 1 iteration 700: 1.1258927583694458
# loss in epoch 1 iteration 800: 1.1080471277236938
# loss in epoch 1 iteration 900: 1.1122419834136963
# loss in epoch 1 iteration 1000: 1.1020481586456299
# loss in epoch 1 iteration 1100: 1.1086832284927368
# loss in epoch 1 iteration 1200: 1.1112143993377686
# loss in epoch 1 iteration 1300: 1.1118680238723755
# loss in epoch 1 iteration 1400: 1.0771541595458984
# loss in epoch 1 iteration 1500: 1.061126947402954
# loss in epoch 1 iteration 1600: 1.076577067375183
# loss in epoch 1 iteration 1700: 1.0782902240753174
# loss in epoch 1 iteration 1800: 1.0417503118515015
# loss in epoch 1 iteration 1900: 1.06808602809906
# loss in epoch 1 iteration 2000: 1.0636446475982666
# loss in epoch 1 iteration 2100: 1.0623337030410767
# loss in epoch 1 iteration 2200: 0.9959502220153809
# loss in epoch 1 iteration 2300: 1.0036970376968384
# loss in epoch 1 iteration 2400: 1.0189987421035767
# loss in epoch 1 iteration 2500: 0.9898391962051392
# loss in epoch 1 iteration 2600: 0.9879294633865356
# loss in epoch 1 iteration 2700: 1.004027009010315
# loss in epoch 1 iteration 2800: 0.9891088008880615
# loss in epoch 1 iteration 2900: 0.964567244052887
# loss in epoch 1 iteration 3000: 0.9621740579605103
# loss in epoch 1 iteration 3100: 0.9729236364364624
# loss in epoch 1 iteration 3200: 0.9419407844543457
# loss in epoch 1 iteration 3300: 0.9641234874725342
# loss in epoch 1 iteration 3400: 0.969646692276001
# loss in epoch 1 iteration 3500: 0.9529710412025452
# loss in epoch 1 iteration 3600: 0.8858392238616943
# loss in epoch 1 iteration 3700: 0.9747204184532166
# loss in epoch 1 iteration 3800: 0.8939131498336792
# loss in epoch 1 iteration 3900: 0.8965505361557007
# loss in epoch 1 iteration 4000: 0.9051434397697449
# loss in epoch 1 iteration 4100: 0.9233105182647705
# loss in epoch 2 iteration 0: 0.9021716713905334
# loss in epoch 2 iteration 100: 0.935917317867279
# loss in epoch 2 iteration 200: 0.8704888820648193
# loss in epoch 2 iteration 300: 0.9393168091773987
# loss in epoch 2 iteration 400: 0.9218429327011108
# loss in epoch 2 iteration 500: 0.912081778049469
# loss in epoch 2 iteration 600: 0.864054799079895
# loss in epoch 2 iteration 700: 0.8799560070037842
# loss in epoch 2 iteration 800: 0.8784370422363281
# loss in epoch 2 iteration 900: 0.9203842282295227
# loss in epoch 2 iteration 1000: 0.8928571939468384
# loss in epoch 2 iteration 1100: 0.8502306342124939
# loss in epoch 2 iteration 1200: 0.8325176239013672
# loss in epoch 2 iteration 1300: 0.8681873083114624
# loss in epoch 2 iteration 1400: 0.8541984558105469
# loss in epoch 2 iteration 1500: 0.8477619290351868
# loss in epoch 2 iteration 1600: 0.9043941497802734
# loss in epoch 2 iteration 1700: 0.7794085144996643
# loss in epoch 2 iteration 1800: 0.795306921005249
# loss in epoch 2 iteration 1900: 0.7839256525039673
# loss in epoch 2 iteration 2000: 0.8570724725723267
# loss in epoch 2 iteration 2100: 0.7834510803222656
# loss in epoch 2 iteration 2200: 0.826803982257843
# loss in epoch 2 iteration 2300: 0.8414502143859863
# loss in epoch 2 iteration 2400: 0.8078494071960449
# loss in epoch 2 iteration 2500: 0.7999197244644165
# loss in epoch 2 iteration 2600: 0.7752218246459961
# loss in epoch 2 iteration 2700: 0.769314706325531
# loss in epoch 2 iteration 2800: 0.7552573680877686
# loss in epoch 2 iteration 2900: 0.8603665828704834
# loss in epoch 2 iteration 3000: 0.8389383554458618
# loss in epoch 2 iteration 3100: 0.724126935005188
# loss in epoch 2 iteration 3200: 0.820887565612793
# loss in epoch 2 iteration 3300: 0.7833378314971924
# loss in epoch 2 iteration 3400: 0.7722907066345215
# loss in epoch 2 iteration 3500: 0.7492246031761169
# loss in epoch 2 iteration 3600: 0.8081504106521606
# loss in epoch 2 iteration 3700: 0.8202371597290039
# loss in epoch 2 iteration 3800: 0.815182089805603
# loss in epoch 2 iteration 3900: 0.7388769388198853
# loss in epoch 2 iteration 4000: 0.7581723928451538
# loss in epoch 2 iteration 4100: 0.7456984519958496
# loss in epoch 3 iteration 0: 0.7365503311157227
# loss in epoch 3 iteration 100: 0.7053161859512329
# loss in epoch 3 iteration 200: 0.7232928276062012
# loss in epoch 3 iteration 300: 0.7501217126846313
# loss in epoch 3 iteration 400: 0.7354062795639038
# loss in epoch 3 iteration 500: 0.7676085233688354
# loss in epoch 3 iteration 600: 0.7258944511413574
# loss in epoch 3 iteration 700: 0.7831960916519165
# loss in epoch 3 iteration 800: 0.783228874206543
# loss in epoch 3 iteration 900: 0.7505515217781067
# loss in epoch 3 iteration 1000: 0.737507700920105
# loss in epoch 3 iteration 1100: 0.71829754114151
# loss in epoch 3 iteration 1200: 0.7230271697044373
# loss in epoch 3 iteration 1300: 0.6750996708869934
# loss in epoch 3 iteration 1400: 0.674558162689209
# loss in epoch 3 iteration 1500: 0.6836183071136475
# loss in epoch 3 iteration 1600: 0.6659250259399414
# loss in epoch 3 iteration 1700: 0.6882603764533997
# loss in epoch 3 iteration 1800: 0.6785169839859009
# loss in epoch 3 iteration 1900: 0.7113254070281982
# loss in epoch 3 iteration 2000: 0.6655255556106567
# loss in epoch 3 iteration 2100: 0.6951518654823303
# loss in epoch 3 iteration 2200: 0.7172049283981323
# loss in epoch 3 iteration 2300: 0.7101494073867798
# loss in epoch 3 iteration 2400: 0.6563296318054199
# loss in epoch 3 iteration 2500: 0.6780758500099182
# loss in epoch 3 iteration 2600: 0.7141141891479492
# loss in epoch 3 iteration 2700: 0.6927305459976196
# loss in epoch 3 iteration 2800: 0.7330416440963745
# loss in epoch 3 iteration 2900: 0.7619702816009521
# loss in epoch 3 iteration 3000: 0.6739904880523682
# loss in epoch 3 iteration 3100: 0.6408218145370483
# loss in epoch 3 iteration 3200: 0.6919383406639099
# loss in epoch 3 iteration 3300: 0.6719610095024109
# loss in epoch 3 iteration 3400: 0.6438133716583252
# loss in epoch 3 iteration 3500: 0.6818166971206665
# loss in epoch 3 iteration 3600: 0.7269757986068726
# loss in epoch 3 iteration 3700: 0.6425340175628662
# loss in epoch 3 iteration 3800: 0.6524357795715332
# loss in epoch 3 iteration 3900: 0.6404250860214233
# loss in epoch 3 iteration 4000: 0.652285635471344
# loss in epoch 3 iteration 4100: 0.666157603263855
# loss in epoch 4 iteration 0: 0.6299034357070923
# loss in epoch 4 iteration 100: 0.6913933753967285
# loss in epoch 4 iteration 200: 0.6776102185249329
# loss in epoch 4 iteration 300: 0.6195265054702759
# loss in epoch 4 iteration 400: 0.6694446802139282
# loss in epoch 4 iteration 500: 0.6581960916519165
# loss in epoch 4 iteration 600: 0.6459495425224304
# loss in epoch 4 iteration 700: 0.6612768173217773
# loss in epoch 4 iteration 800: 0.6190179586410522
# loss in epoch 4 iteration 900: 0.6005462408065796
# loss in epoch 4 iteration 1000: 0.6526472568511963
# loss in epoch 4 iteration 1100: 0.6076766848564148
# loss in epoch 4 iteration 1200: 0.6141471862792969
# loss in epoch 4 iteration 1300: 0.6373927593231201
# loss in epoch 4 iteration 1400: 0.605434000492096
# loss in epoch 4 iteration 1500: 0.6752204298973083
# loss in epoch 4 iteration 1600: 0.6202144622802734
# loss in epoch 4 iteration 1700: 0.7087593674659729
# loss in epoch 4 iteration 1800: 0.6083610653877258
# loss in epoch 4 iteration 1900: 0.6397398710250854
# loss in epoch 4 iteration 2000: 0.6239448189735413
# loss in epoch 4 iteration 2100: 0.5820534229278564
# loss in epoch 4 iteration 2200: 0.6238083243370056
# loss in epoch 4 iteration 2300: 0.6021136045455933
# loss in epoch 4 iteration 2400: 0.6301209330558777
# loss in epoch 4 iteration 2500: 0.6599259972572327
# loss in epoch 4 iteration 2600: 0.5868657827377319
# loss in epoch 4 iteration 2700: 0.5998697280883789
# loss in epoch 4 iteration 2800: 0.6337258815765381
# loss in epoch 4 iteration 2900: 0.6103290915489197
# loss in epoch 4 iteration 3000: 0.546890139579773
# loss in epoch 4 iteration 3100: 0.5678536891937256
# loss in epoch 4 iteration 3200: 0.599149227142334
# loss in epoch 4 iteration 3300: 0.5891261100769043
# loss in epoch 4 iteration 3400: 0.5910202860832214
# loss in epoch 4 iteration 3500: 0.595112681388855
# loss in epoch 4 iteration 3600: 0.6332283020019531
# loss in epoch 4 iteration 3700: 0.520697295665741
# loss in epoch 4 iteration 3800: 0.6090385317802429
# loss in epoch 4 iteration 3900: 0.5596508979797363
# loss in epoch 4 iteration 4000: 0.6151441335678101
# loss in epoch 4 iteration 4100: 0.5694053173065186
# loss in epoch 5 iteration 0: 0.5813571810722351
# loss in epoch 5 iteration 100: 0.6085823178291321
# loss in epoch 5 iteration 200: 0.5504500269889832
# loss in epoch 5 iteration 300: 0.5776306986808777
# loss in epoch 5 iteration 400: 0.5461118221282959
# loss in epoch 5 iteration 500: 0.52732253074646
# loss in epoch 5 iteration 600: 0.5873122811317444
# loss in epoch 5 iteration 700: 0.580375611782074
# loss in epoch 5 iteration 800: 0.4909076690673828
# loss in epoch 5 iteration 900: 0.6574349999427795
# loss in epoch 5 iteration 1000: 0.5668083429336548
# loss in epoch 5 iteration 1100: 0.566565752029419
# loss in epoch 5 iteration 1200: 0.5800851583480835
# loss in epoch 5 iteration 1300: 0.5614837408065796
# loss in epoch 5 iteration 1400: 0.560627818107605
# loss in epoch 5 iteration 1500: 0.5062373280525208
# loss in epoch 5 iteration 1600: 0.5654908418655396
# loss in epoch 5 iteration 1700: 0.5446020364761353
# loss in epoch 5 iteration 1800: 0.5351723432540894
# loss in epoch 5 iteration 1900: 0.5512978434562683
# loss in epoch 5 iteration 2000: 0.5186801552772522
# loss in epoch 5 iteration 2100: 0.5937079787254333
# loss in epoch 5 iteration 2200: 0.5298100113868713
# loss in epoch 5 iteration 2300: 0.593527615070343
# loss in epoch 5 iteration 2400: 0.565672755241394
# loss in epoch 5 iteration 2500: 0.5748404264450073
# loss in epoch 5 iteration 2600: 0.49951863288879395
# loss in epoch 5 iteration 2700: 0.5571314096450806
# loss in epoch 5 iteration 2800: 0.5961745977401733
# loss in epoch 5 iteration 2900: 0.533647358417511
# loss in epoch 5 iteration 3000: 0.5502314567565918
# loss in epoch 5 iteration 3100: 0.5438514947891235
# loss in epoch 5 iteration 3200: 0.521906316280365
# loss in epoch 5 iteration 3300: 0.5740896463394165
# loss in epoch 5 iteration 3400: 0.5212659239768982
# loss in epoch 5 iteration 3500: 0.49948039650917053
# loss in epoch 5 iteration 3600: 0.49360716342926025
# loss in epoch 5 iteration 3700: 0.5338091254234314
# loss in epoch 5 iteration 3800: 0.5180749297142029
# loss in epoch 5 iteration 3900: 0.5458841919898987
# loss in epoch 5 iteration 4000: 0.4850602149963379
# loss in epoch 5 iteration 4100: 0.5290469527244568
# loss in epoch 6 iteration 0: 0.5797865390777588
# loss in epoch 6 iteration 100: 0.5253788232803345
# loss in epoch 6 iteration 200: 0.4712843596935272
# loss in epoch 6 iteration 300: 0.5484853386878967
# loss in epoch 6 iteration 400: 0.5467571020126343
# loss in epoch 6 iteration 500: 0.4555715024471283
# loss in epoch 6 iteration 600: 0.48585471510887146
# loss in epoch 6 iteration 700: 0.5361928343772888
# loss in epoch 6 iteration 800: 0.46961989998817444
# loss in epoch 6 iteration 900: 0.49782776832580566
# loss in epoch 6 iteration 1000: 0.5368058681488037
# loss in epoch 6 iteration 1100: 0.4997097849845886
# loss in epoch 6 iteration 1200: 0.5126836895942688
# loss in epoch 6 iteration 1300: 0.4515812397003174
# loss in epoch 6 iteration 1400: 0.48438751697540283
# loss in epoch 6 iteration 1500: 0.5122630000114441
# loss in epoch 6 iteration 1600: 0.47713059186935425
# loss in epoch 6 iteration 1700: 0.4787558317184448
# loss in epoch 6 iteration 1800: 0.46978673338890076
# loss in epoch 6 iteration 1900: 0.5161504745483398
# loss in epoch 6 iteration 2000: 0.46827659010887146
# loss in epoch 6 iteration 2100: 0.4407387673854828
# loss in epoch 6 iteration 2200: 0.49102890491485596
# loss in epoch 6 iteration 2300: 0.48943406343460083
# loss in epoch 6 iteration 2400: 0.49712690711021423
# loss in epoch 6 iteration 2500: 0.5091026425361633
# loss in epoch 6 iteration 2600: 0.5049539804458618
# loss in epoch 6 iteration 2700: 0.5320941209793091
# loss in epoch 6 iteration 2800: 0.47982221841812134
# loss in epoch 6 iteration 2900: 0.44438987970352173
# loss in epoch 6 iteration 3000: 0.4819154143333435
# loss in epoch 6 iteration 3100: 0.44723373651504517
# loss in epoch 6 iteration 3200: 0.47990572452545166
# loss in epoch 6 iteration 3300: 0.4666908085346222
# loss in epoch 6 iteration 3400: 0.4824584424495697
# loss in epoch 6 iteration 3500: 0.5309982299804688
# loss in epoch 6 iteration 3600: 0.49155861139297485
# loss in epoch 6 iteration 3700: 0.5116548538208008
# loss in epoch 6 iteration 3800: 0.46463504433631897
# loss in epoch 6 iteration 3900: 0.52890545129776
# loss in epoch 6 iteration 4000: 0.5366452932357788
# loss in epoch 6 iteration 4100: 0.4819398522377014
# loss in epoch 7 iteration 0: 0.4540918469429016
# loss in epoch 7 iteration 100: 0.45678871870040894
# loss in epoch 7 iteration 200: 0.4554542899131775
# loss in epoch 7 iteration 300: 0.518791913986206
# loss in epoch 7 iteration 400: 0.47780388593673706
# loss in epoch 7 iteration 500: 0.48977434635162354
# loss in epoch 7 iteration 600: 0.48551657795906067
# loss in epoch 7 iteration 700: 0.43710267543792725
# loss in epoch 7 iteration 800: 0.490539014339447
# loss in epoch 7 iteration 900: 0.4570187032222748
# loss in epoch 7 iteration 1000: 0.4790906310081482
# loss in epoch 7 iteration 1100: 0.44748401641845703
# loss in epoch 7 iteration 1200: 0.45105117559432983
# loss in epoch 7 iteration 1300: 0.44664648175239563
# loss in epoch 7 iteration 1400: 0.4734513759613037
# loss in epoch 7 iteration 1500: 0.462979257106781
# loss in epoch 7 iteration 1600: 0.5471020936965942
# loss in epoch 7 iteration 1700: 0.5371209383010864
# loss in epoch 7 iteration 1800: 0.5043801069259644
# loss in epoch 7 iteration 1900: 0.41792890429496765
# loss in epoch 7 iteration 2000: 0.3766744136810303
# loss in epoch 7 iteration 2100: 0.5145465731620789
# loss in epoch 7 iteration 2200: 0.4484173655509949
# loss in epoch 7 iteration 2300: 0.48108404874801636
# loss in epoch 7 iteration 2400: 0.44463878870010376
# loss in epoch 7 iteration 2500: 0.46383506059646606
# loss in epoch 7 iteration 2600: 0.44102683663368225
# loss in epoch 7 iteration 2700: 0.4888339936733246
# loss in epoch 7 iteration 2800: 0.4638075828552246
# loss in epoch 7 iteration 2900: 0.4283541440963745
# loss in epoch 7 iteration 3000: 0.4371291697025299
# loss in epoch 7 iteration 3100: 0.4276401996612549
# loss in epoch 7 iteration 3200: 0.4683866798877716
# loss in epoch 7 iteration 3300: 0.44177883863449097
# loss in epoch 7 iteration 3400: 0.4212297201156616
# loss in epoch 7 iteration 3500: 0.4208691716194153
# loss in epoch 7 iteration 3600: 0.37668636441230774
# loss in epoch 7 iteration 3700: 0.4815202057361603
# loss in epoch 7 iteration 3800: 0.41226375102996826
# loss in epoch 7 iteration 3900: 0.3771723508834839
# loss in epoch 7 iteration 4000: 0.4090697765350342
# loss in epoch 7 iteration 4100: 0.43181341886520386
# loss in epoch 8 iteration 0: 0.36623692512512207
# loss in epoch 8 iteration 100: 0.4223855435848236
# loss in epoch 8 iteration 200: 0.47228574752807617
# loss in epoch 8 iteration 300: 0.42637282609939575
# loss in epoch 8 iteration 400: 0.40214815735816956
# loss in epoch 8 iteration 500: 0.46606647968292236
# loss in epoch 8 iteration 600: 0.3974369168281555
# loss in epoch 8 iteration 700: 0.4484739303588867
# loss in epoch 8 iteration 800: 0.35295453667640686
# loss in epoch 8 iteration 900: 0.406399667263031
# loss in epoch 8 iteration 1000: 0.4336570203304291
# loss in epoch 8 iteration 1100: 0.4574486315250397
# loss in epoch 8 iteration 1200: 0.4342133700847626
# loss in epoch 8 iteration 1300: 0.3904612362384796
# loss in epoch 8 iteration 1400: 0.39727914333343506
# loss in epoch 8 iteration 1500: 0.4095737338066101
# loss in epoch 8 iteration 1600: 0.39747706055641174
# loss in epoch 8 iteration 1700: 0.47055941820144653
# loss in epoch 8 iteration 1800: 0.45835623145103455
# loss in epoch 8 iteration 1900: 0.3850366473197937
# loss in epoch 8 iteration 2000: 0.34602734446525574
# loss in epoch 8 iteration 2100: 0.37948960065841675
# loss in epoch 8 iteration 2200: 0.4589104652404785
# loss in epoch 8 iteration 2300: 0.43367838859558105
# loss in epoch 8 iteration 2400: 0.46215587854385376
# loss in epoch 8 iteration 2500: 0.40140050649642944
# loss in epoch 8 iteration 2600: 0.44172316789627075
# loss in epoch 8 iteration 2700: 0.4083155393600464
# loss in epoch 8 iteration 2800: 0.4205567240715027
# loss in epoch 8 iteration 2900: 0.36619943380355835
# loss in epoch 8 iteration 3000: 0.3734045624732971
# loss in epoch 8 iteration 3100: 0.4463711380958557
# loss in epoch 8 iteration 3200: 0.4180649518966675
# loss in epoch 8 iteration 3300: 0.4152154326438904
# loss in epoch 8 iteration 3400: 0.35458117723464966
# loss in epoch 8 iteration 3500: 0.38183408975601196
# loss in epoch 8 iteration 3600: 0.35199928283691406
# loss in epoch 8 iteration 3700: 0.41977646946907043
# loss in epoch 8 iteration 3800: 0.3627667725086212
# loss in epoch 8 iteration 3900: 0.34973418712615967
# loss in epoch 8 iteration 4000: 0.372811883687973
# loss in epoch 8 iteration 4100: 0.3914814293384552
# loss in epoch 9 iteration 0: 0.4006476402282715
# loss in epoch 9 iteration 100: 0.4521447420120239
# loss in epoch 9 iteration 200: 0.35730648040771484
# loss in epoch 9 iteration 300: 0.3755760192871094
# loss in epoch 9 iteration 400: 0.41348230838775635
# loss in epoch 9 iteration 500: 0.4070766568183899
# loss in epoch 9 iteration 600: 0.45231956243515015
# loss in epoch 9 iteration 700: 0.4437340497970581
# loss in epoch 9 iteration 800: 0.3796175420284271
# loss in epoch 9 iteration 900: 0.3388681709766388
# loss in epoch 9 iteration 1000: 0.41069504618644714
# loss in epoch 9 iteration 1100: 0.3960648775100708
# loss in epoch 9 iteration 1200: 0.408175528049469
# loss in epoch 9 iteration 1300: 0.4039079248905182
# loss in epoch 9 iteration 1400: 0.32645362615585327
# loss in epoch 9 iteration 1500: 0.3843953609466553
# loss in epoch 9 iteration 1600: 0.35320624709129333
# loss in epoch 9 iteration 1700: 0.4120602309703827
# loss in epoch 9 iteration 1800: 0.39452052116394043
# loss in epoch 9 iteration 1900: 0.4043429493904114
# loss in epoch 9 iteration 2000: 0.3644421696662903
# loss in epoch 9 iteration 2100: 0.4371483623981476
# loss in epoch 9 iteration 2200: 0.36879122257232666
# loss in epoch 9 iteration 2300: 0.3620378077030182
# loss in epoch 9 iteration 2400: 0.36927881836891174
# loss in epoch 9 iteration 2500: 0.36944687366485596
# loss in epoch 9 iteration 2600: 0.4243152141571045
# loss in epoch 9 iteration 2700: 0.4155816435813904
# loss in epoch 9 iteration 2800: 0.41360029578208923
# loss in epoch 9 iteration 2900: 0.3351812958717346
# loss in epoch 9 iteration 3000: 0.39940136671066284
# loss in epoch 9 iteration 3100: 0.42548879981040955
# loss in epoch 9 iteration 3200: 0.3980659246444702
# loss in epoch 9 iteration 3300: 0.3726712763309479
# loss in epoch 9 iteration 3400: 0.3556770384311676
# loss in epoch 9 iteration 3500: 0.34440016746520996
# loss in epoch 9 iteration 3600: 0.38647937774658203
# loss in epoch 9 iteration 3700: 0.37647730112075806
# loss in epoch 9 iteration 3800: 0.36810922622680664
# loss in epoch 9 iteration 3900: 0.46178948879241943
# loss in epoch 9 iteration 4000: 0.343630313873291
# loss in epoch 9 iteration 4100: 0.3908904492855072
# loss in epoch 10 iteration 0: 0.34497907757759094
# loss in epoch 10 iteration 100: 0.3310795724391937
# loss in epoch 10 iteration 200: 0.3700698912143707
# loss in epoch 10 iteration 300: 0.42722856998443604
# loss in epoch 10 iteration 400: 0.4091319441795349
# loss in epoch 10 iteration 500: 0.35482850670814514
# loss in epoch 10 iteration 600: 0.37977346777915955
# loss in epoch 10 iteration 700: 0.37965530157089233
# loss in epoch 10 iteration 800: 0.41596290469169617
# loss in epoch 10 iteration 900: 0.3664858043193817
# loss in epoch 10 iteration 1000: 0.3799620270729065
# loss in epoch 10 iteration 1100: 0.4122619032859802
# loss in epoch 10 iteration 1200: 0.32249715924263
# loss in epoch 10 iteration 1300: 0.38761621713638306
# loss in epoch 10 iteration 1400: 0.3117464482784271
# loss in epoch 10 iteration 1500: 0.3713507056236267
# loss in epoch 10 iteration 1600: 0.3220551311969757
# loss in epoch 10 iteration 1700: 0.3918459415435791
# loss in epoch 10 iteration 1800: 0.36552318930625916
# loss in epoch 10 iteration 1900: 0.3950234353542328
# loss in epoch 10 iteration 2000: 0.35634559392929077
# loss in epoch 10 iteration 2100: 0.3512907326221466
# loss in epoch 10 iteration 2200: 0.39319074153900146
# loss in epoch 10 iteration 2300: 0.3875342607498169
# loss in epoch 10 iteration 2400: 0.3794923424720764
# loss in epoch 10 iteration 2500: 0.34668222069740295
# loss in epoch 10 iteration 2600: 0.3496245741844177
# loss in epoch 10 iteration 2700: 0.35334089398384094
# loss in epoch 10 iteration 2800: 0.35506221652030945
# loss in epoch 10 iteration 2900: 0.33422136306762695
# loss in epoch 10 iteration 3000: 0.3769201934337616
# loss in epoch 10 iteration 3100: 0.37043672800064087
# loss in epoch 10 iteration 3200: 0.35621020197868347
# loss in epoch 10 iteration 3300: 0.3634970486164093
# loss in epoch 10 iteration 3400: 0.3975136876106262
# loss in epoch 10 iteration 3500: 0.4259285628795624
# loss in epoch 10 iteration 3600: 0.349197655916214
# loss in epoch 10 iteration 3700: 0.36097094416618347
# loss in epoch 10 iteration 3800: 0.3304627537727356
# loss in epoch 10 iteration 3900: 0.386189341545105
# loss in epoch 10 iteration 4000: 0.2965804934501648
# loss in epoch 10 iteration 4100: 0.3021116852760315
# loss in epoch 11 iteration 0: 0.3966958522796631
# loss in epoch 11 iteration 100: 0.34561121463775635
# loss in epoch 11 iteration 200: 0.35716235637664795
# loss in epoch 11 iteration 300: 0.38174062967300415
# loss in epoch 11 iteration 400: 0.3631674647331238
# loss in epoch 11 iteration 500: 0.32284632325172424
# loss in epoch 11 iteration 600: 0.40590810775756836
# loss in epoch 11 iteration 700: 0.3230460584163666
# loss in epoch 11 iteration 800: 0.3559076189994812
# loss in epoch 11 iteration 900: 0.328108012676239
# loss in epoch 11 iteration 1000: 0.35800400376319885
# loss in epoch 11 iteration 1100: 0.34361532330513
# loss in epoch 11 iteration 1200: 0.32629382610321045
# loss in epoch 11 iteration 1300: 0.3184879422187805
# loss in epoch 11 iteration 1400: 0.3846766948699951
# loss in epoch 11 iteration 1500: 0.37176135182380676
# loss in epoch 11 iteration 1600: 0.3267136514186859
# loss in epoch 11 iteration 1700: 0.3394460082054138
# loss in epoch 11 iteration 1800: 0.420695036649704
# loss in epoch 11 iteration 1900: 0.3755415678024292
# loss in epoch 11 iteration 2000: 0.33551138639450073
# loss in epoch 11 iteration 2100: 0.3495020866394043
# loss in epoch 11 iteration 2200: 0.33937862515449524
# loss in epoch 11 iteration 2300: 0.32393017411231995
# loss in epoch 11 iteration 2400: 0.369096040725708
# loss in epoch 11 iteration 2500: 0.36280542612075806
# loss in epoch 11 iteration 2600: 0.3566194176673889
# loss in epoch 11 iteration 2700: 0.3289637267589569
# loss in epoch 11 iteration 2800: 0.31223225593566895
# loss in epoch 11 iteration 2900: 0.3225756287574768
# loss in epoch 11 iteration 3000: 0.3085283041000366
# loss in epoch 11 iteration 3100: 0.3473331332206726
# loss in epoch 11 iteration 3200: 0.34832388162612915
# loss in epoch 11 iteration 3300: 0.3125848174095154
# loss in epoch 11 iteration 3400: 0.36530932784080505
# loss in epoch 11 iteration 3500: 0.3193768262863159
# loss in epoch 11 iteration 3600: 0.3429183065891266
# loss in epoch 11 iteration 3700: 0.3292534649372101
# loss in epoch 11 iteration 3800: 0.35382941365242004
# loss in epoch 11 iteration 3900: 0.2913402318954468
# loss in epoch 11 iteration 4000: 0.3121466338634491
# loss in epoch 11 iteration 4100: 0.3042372465133667
# loss in epoch 12 iteration 0: 0.2946377098560333
# loss in epoch 12 iteration 100: 0.3447238504886627
# loss in epoch 12 iteration 200: 0.3777020573616028
# loss in epoch 12 iteration 300: 0.31639930605888367
# loss in epoch 12 iteration 400: 0.30982705950737
# loss in epoch 12 iteration 500: 0.2857382297515869
# loss in epoch 12 iteration 600: 0.3219583332538605
# loss in epoch 12 iteration 700: 0.29961639642715454
# loss in epoch 12 iteration 800: 0.30398112535476685
# loss in epoch 12 iteration 900: 0.28615060448646545
# loss in epoch 12 iteration 1000: 0.31124356389045715
# loss in epoch 12 iteration 1100: 0.3025394082069397
# loss in epoch 12 iteration 1200: 0.39555567502975464
# loss in epoch 12 iteration 1300: 0.3569640517234802
# loss in epoch 12 iteration 1400: 0.32938793301582336
# loss in epoch 12 iteration 1500: 0.3222891390323639
# loss in epoch 12 iteration 1600: 0.3293905258178711
# loss in epoch 12 iteration 1700: 0.3011060655117035
# loss in epoch 12 iteration 1800: 0.3119185268878937
# loss in epoch 12 iteration 1900: 0.306412935256958
# loss in epoch 12 iteration 2000: 0.350043386220932
# loss in epoch 12 iteration 2100: 0.3708685636520386
# loss in epoch 12 iteration 2200: 0.31513088941574097
# loss in epoch 12 iteration 2300: 0.3352077007293701
# loss in epoch 12 iteration 2400: 0.3632105588912964
# loss in epoch 12 iteration 2500: 0.28552985191345215
# loss in epoch 12 iteration 2600: 0.31072330474853516
# loss in epoch 12 iteration 2700: 0.33158332109451294
# loss in epoch 12 iteration 2800: 0.3194418251514435
# loss in epoch 12 iteration 2900: 0.34022846817970276
# loss in epoch 12 iteration 3000: 0.31342312693595886
# loss in epoch 12 iteration 3100: 0.34718671441078186
# loss in epoch 12 iteration 3200: 0.318580687046051
# loss in epoch 12 iteration 3300: 0.3021913766860962
# loss in epoch 12 iteration 3400: 0.30454525351524353
# loss in epoch 12 iteration 3500: 0.32217836380004883
# loss in epoch 12 iteration 3600: 0.2950998842716217
# loss in epoch 12 iteration 3700: 0.33789846301078796
# loss in epoch 12 iteration 3800: 0.3786080777645111
# loss in epoch 12 iteration 3900: 0.3063106834888458
# loss in epoch 12 iteration 4000: 0.3407483398914337
# loss in epoch 12 iteration 4100: 0.30946701765060425
# loss in epoch 13 iteration 0: 0.2837395668029785
# loss in epoch 13 iteration 100: 0.3075433373451233
# loss in epoch 13 iteration 200: 0.29703712463378906
# loss in epoch 13 iteration 300: 0.34186044335365295
# loss in epoch 13 iteration 400: 0.3405073285102844
# loss in epoch 13 iteration 500: 0.3285757899284363
# loss in epoch 13 iteration 600: 0.34518682956695557
# loss in epoch 13 iteration 700: 0.33372122049331665
# loss in epoch 13 iteration 800: 0.3167206645011902
# loss in epoch 13 iteration 900: 0.35099804401397705
# loss in epoch 13 iteration 1000: 0.3360174298286438
# loss in epoch 13 iteration 1100: 0.363753080368042
# loss in epoch 13 iteration 1200: 0.28484857082366943
# loss in epoch 13 iteration 1300: 0.3416890501976013
# loss in epoch 13 iteration 1400: 0.32923197746276855
# loss in epoch 13 iteration 1500: 0.31433194875717163
# loss in epoch 13 iteration 1600: 0.34375235438346863
# loss in epoch 13 iteration 1700: 0.27303335070610046
# loss in epoch 13 iteration 1800: 0.2999502718448639
# loss in epoch 13 iteration 1900: 0.31357714533805847
# loss in epoch 13 iteration 2000: 0.32357949018478394
# loss in epoch 13 iteration 2100: 0.29586708545684814
# loss in epoch 13 iteration 2200: 0.3050250709056854
# loss in epoch 13 iteration 2300: 0.2838701605796814
# loss in epoch 13 iteration 2400: 0.2884741425514221
# loss in epoch 13 iteration 2500: 0.2861872911453247
# loss in epoch 13 iteration 2600: 0.3207590579986572
# loss in epoch 13 iteration 2700: 0.2638421654701233
# loss in epoch 13 iteration 2800: 0.3000279366970062
# loss in epoch 13 iteration 2900: 0.2887856662273407
# loss in epoch 13 iteration 3000: 0.31652534008026123
# loss in epoch 13 iteration 3100: 0.284106582403183
# loss in epoch 13 iteration 3200: 0.3461727499961853
# loss in epoch 13 iteration 3300: 0.3177691698074341
# loss in epoch 13 iteration 3400: 0.28153708577156067
# loss in epoch 13 iteration 3500: 0.32944217324256897
# loss in epoch 13 iteration 3600: 0.28673258423805237
# loss in epoch 13 iteration 3700: 0.28841617703437805
# loss in epoch 13 iteration 3800: 0.3150996267795563
# loss in epoch 13 iteration 3900: 0.3160085678100586
# loss in epoch 13 iteration 4000: 0.28092220425605774
# loss in epoch 13 iteration 4100: 0.29983118176460266
# loss in epoch 14 iteration 0: 0.32353460788726807
# loss in epoch 14 iteration 100: 0.28224119544029236
# loss in epoch 14 iteration 200: 0.35100823640823364
# loss in epoch 14 iteration 300: 0.2637169361114502
# loss in epoch 14 iteration 400: 0.3070313036441803
# loss in epoch 14 iteration 500: 0.3304455578327179
# loss in epoch 14 iteration 600: 0.3270021975040436
# loss in epoch 14 iteration 700: 0.29615795612335205
# loss in epoch 14 iteration 800: 0.3435293436050415
# loss in epoch 14 iteration 900: 0.2834562361240387
# loss in epoch 14 iteration 1000: 0.2798805832862854
# loss in epoch 14 iteration 1100: 0.27602487802505493
# loss in epoch 14 iteration 1200: 0.3016971945762634
# loss in epoch 14 iteration 1300: 0.31012338399887085
# loss in epoch 14 iteration 1400: 0.29015445709228516
# loss in epoch 14 iteration 1500: 0.3424403667449951
# loss in epoch 14 iteration 1600: 0.27839982509613037
# loss in epoch 14 iteration 1700: 0.3233815133571625
# loss in epoch 14 iteration 1800: 0.31269770860671997
# loss in epoch 14 iteration 1900: 0.30372461676597595
# loss in epoch 14 iteration 2000: 0.27218085527420044
# loss in epoch 14 iteration 2100: 0.3101893961429596
# loss in epoch 14 iteration 2200: 0.29858309030532837
# loss in epoch 14 iteration 2300: 0.28053656220436096
# loss in epoch 14 iteration 2400: 0.26687291264533997
# loss in epoch 14 iteration 2500: 0.3164709508419037
# loss in epoch 14 iteration 2600: 0.30165529251098633
# loss in epoch 14 iteration 2700: 0.29174697399139404
# loss in epoch 14 iteration 2800: 0.2844819724559784
# loss in epoch 14 iteration 2900: 0.28074610233306885
# loss in epoch 14 iteration 3000: 0.2661614418029785
# loss in epoch 14 iteration 3100: 0.30967968702316284
# loss in epoch 14 iteration 3200: 0.32371050119400024
# loss in epoch 14 iteration 3300: 0.28897416591644287
# loss in epoch 14 iteration 3400: 0.33426809310913086
# loss in epoch 14 iteration 3500: 0.30809080600738525
# loss in epoch 14 iteration 3600: 0.24182075262069702
# loss in epoch 14 iteration 3700: 0.31352323293685913
# loss in epoch 14 iteration 3800: 0.2594197690486908
# loss in epoch 14 iteration 3900: 0.32648271322250366
# loss in epoch 14 iteration 4000: 0.23931363224983215
# loss in epoch 14 iteration 4100: 0.23401281237602234
# loss in epoch 15 iteration 0: 0.2844642996788025
# loss in epoch 15 iteration 100: 0.28619375824928284
# loss in epoch 15 iteration 200: 0.26131314039230347
# loss in epoch 15 iteration 300: 0.2937171161174774
# loss in epoch 15 iteration 400: 0.2843961715698242
# loss in epoch 15 iteration 500: 0.26963454484939575
# loss in epoch 15 iteration 600: 0.27323728799819946
# loss in epoch 15 iteration 700: 0.26304516196250916
# loss in epoch 15 iteration 800: 0.2716270983219147
# loss in epoch 15 iteration 900: 0.29165562987327576
# loss in epoch 15 iteration 1000: 0.3020121157169342
# loss in epoch 15 iteration 1100: 0.2404150664806366
# loss in epoch 15 iteration 1200: 0.26060569286346436
# loss in epoch 15 iteration 1300: 0.29136934876441956
# loss in epoch 15 iteration 1400: 0.27999311685562134
# loss in epoch 15 iteration 1500: 0.2996606230735779
# loss in epoch 15 iteration 1600: 0.2682749032974243
# loss in epoch 15 iteration 1700: 0.26433318853378296
# loss in epoch 15 iteration 1800: 0.3045891523361206
# loss in epoch 15 iteration 1900: 0.26972758769989014
# loss in epoch 15 iteration 2000: 0.26582813262939453
# loss in epoch 15 iteration 2100: 0.2502250075340271
# loss in epoch 15 iteration 2200: 0.2973068952560425
# loss in epoch 15 iteration 2300: 0.32681480050086975
# loss in epoch 15 iteration 2400: 0.2956804633140564
# loss in epoch 15 iteration 2500: 0.2835531532764435
# loss in epoch 15 iteration 2600: 0.29985642433166504
# loss in epoch 15 iteration 2700: 0.28402179479599
# loss in epoch 15 iteration 2800: 0.27837640047073364
# loss in epoch 15 iteration 2900: 0.28717920184135437
# loss in epoch 15 iteration 3000: 0.3034575283527374
# loss in epoch 15 iteration 3100: 0.23190045356750488
# loss in epoch 15 iteration 3200: 0.2746695578098297
# loss in epoch 15 iteration 3300: 0.2837441861629486
# loss in epoch 15 iteration 3400: 0.24150148034095764
# loss in epoch 15 iteration 3500: 0.2579944133758545
# loss in epoch 15 iteration 3600: 0.2897559702396393
# loss in epoch 15 iteration 3700: 0.2773183286190033
# loss in epoch 15 iteration 3800: 0.2928500175476074
# loss in epoch 15 iteration 3900: 0.27015364170074463
# loss in epoch 15 iteration 4000: 0.25701603293418884
# loss in epoch 15 iteration 4100: 0.2366132289171219
# loss in epoch 16 iteration 0: 0.2754274904727936
# loss in epoch 16 iteration 100: 0.28769779205322266
# loss in epoch 16 iteration 200: 0.2695336937904358
# loss in epoch 16 iteration 300: 0.22795674204826355
# loss in epoch 16 iteration 400: 0.29212480783462524
# loss in epoch 16 iteration 500: 0.294453501701355
# loss in epoch 16 iteration 600: 0.29708439111709595
# loss in epoch 16 iteration 700: 0.2613206207752228
# loss in epoch 16 iteration 800: 0.23798060417175293
# loss in epoch 16 iteration 900: 0.2492770105600357
# loss in epoch 16 iteration 1000: 0.26523351669311523
# loss in epoch 16 iteration 1100: 0.22805429995059967
# loss in epoch 16 iteration 1200: 0.2941949963569641
# loss in epoch 16 iteration 1300: 0.26400211453437805
# loss in epoch 16 iteration 1400: 0.2904961109161377
# loss in epoch 16 iteration 1500: 0.324368417263031
# loss in epoch 16 iteration 1600: 0.2544539272785187
# loss in epoch 16 iteration 1700: 0.2266925722360611
# loss in epoch 16 iteration 1800: 0.2610653042793274
# loss in epoch 16 iteration 1900: 0.26541346311569214
# loss in epoch 16 iteration 2000: 0.25335627794265747
# loss in epoch 16 iteration 2100: 0.26667726039886475
# loss in epoch 16 iteration 2200: 0.2721640467643738
# loss in epoch 16 iteration 2300: 0.2343675196170807
# loss in epoch 16 iteration 2400: 0.2629862427711487
# loss in epoch 16 iteration 2500: 0.28381916880607605
# loss in epoch 16 iteration 2600: 0.25426265597343445
# loss in epoch 16 iteration 2700: 0.2542514204978943
# loss in epoch 16 iteration 2800: 0.29273346066474915
# loss in epoch 16 iteration 2900: 0.2488243281841278
# loss in epoch 16 iteration 3000: 0.23128831386566162
# loss in epoch 16 iteration 3100: 0.23329558968544006
# loss in epoch 16 iteration 3200: 0.2888483703136444
# loss in epoch 16 iteration 3300: 0.26540234684944153
# loss in epoch 16 iteration 3400: 0.24417588114738464
# loss in epoch 16 iteration 3500: 0.2578275799751282
# loss in epoch 16 iteration 3600: 0.28831905126571655
# loss in epoch 16 iteration 3700: 0.319581001996994
# loss in epoch 16 iteration 3800: 0.22687160968780518
# loss in epoch 16 iteration 3900: 0.31323686242103577
# loss in epoch 16 iteration 4000: 0.2732716202735901
# loss in epoch 16 iteration 4100: 0.2556283473968506
# loss in epoch 17 iteration 0: 0.2606048882007599
# loss in epoch 17 iteration 100: 0.2345975935459137
# loss in epoch 17 iteration 200: 0.2634741961956024
# loss in epoch 17 iteration 300: 0.2567615807056427
# loss in epoch 17 iteration 400: 0.25415945053100586
# loss in epoch 17 iteration 500: 0.23897254467010498
# loss in epoch 17 iteration 600: 0.2775518298149109
# loss in epoch 17 iteration 700: 0.24620969593524933
# loss in epoch 17 iteration 800: 0.2946573495864868
# loss in epoch 17 iteration 900: 0.2457350343465805
# loss in epoch 17 iteration 1000: 0.3033382296562195
# loss in epoch 17 iteration 1100: 0.25975048542022705
# loss in epoch 17 iteration 1200: 0.26764121651649475
# loss in epoch 17 iteration 1300: 0.3168947100639343
# loss in epoch 17 iteration 1400: 0.20494019985198975
# loss in epoch 17 iteration 1500: 0.29975712299346924
# loss in epoch 17 iteration 1600: 0.2439262717962265
# loss in epoch 17 iteration 1700: 0.2209521234035492
# loss in epoch 17 iteration 1800: 0.2529616355895996
# loss in epoch 17 iteration 1900: 0.2314807027578354
# loss in epoch 17 iteration 2000: 0.28138038516044617
# loss in epoch 17 iteration 2100: 0.23415499925613403
# loss in epoch 17 iteration 2200: 0.283944696187973
# loss in epoch 17 iteration 2300: 0.25014179944992065
# loss in epoch 17 iteration 2400: 0.25691041350364685
# loss in epoch 17 iteration 2500: 0.2858497202396393
# loss in epoch 17 iteration 2600: 0.258303165435791
# loss in epoch 17 iteration 2700: 0.23396272957324982
# loss in epoch 17 iteration 2800: 0.2580912411212921
# loss in epoch 17 iteration 2900: 0.25750792026519775
# loss in epoch 17 iteration 3000: 0.254944771528244
# loss in epoch 17 iteration 3100: 0.23657432198524475
# loss in epoch 17 iteration 3200: 0.31696847081184387
# loss in epoch 17 iteration 3300: 0.2862675189971924
# loss in epoch 17 iteration 3400: 0.24724268913269043
# loss in epoch 17 iteration 3500: 0.27839410305023193
# loss in epoch 17 iteration 3600: 0.2587255537509918
# loss in epoch 17 iteration 3700: 0.22237199544906616
# loss in epoch 17 iteration 3800: 0.2808528542518616
# loss in epoch 17 iteration 3900: 0.2917501628398895
# loss in epoch 17 iteration 4000: 0.2590465545654297
# loss in epoch 17 iteration 4100: 0.24990151822566986
# loss in epoch 18 iteration 0: 0.22367896139621735
# loss in epoch 18 iteration 100: 0.26079991459846497
# loss in epoch 18 iteration 200: 0.23280775547027588
# loss in epoch 18 iteration 300: 0.22452202439308167
# loss in epoch 18 iteration 400: 0.24953773617744446
# loss in epoch 18 iteration 500: 0.23606950044631958
# loss in epoch 18 iteration 600: 0.25131168961524963
# loss in epoch 18 iteration 700: 0.23775829374790192
# loss in epoch 18 iteration 800: 0.2454259991645813
# loss in epoch 18 iteration 900: 0.2674367129802704
# loss in epoch 18 iteration 1000: 0.27234768867492676
# loss in epoch 18 iteration 1100: 0.2654843032360077
# loss in epoch 18 iteration 1200: 0.24222151935100555
# loss in epoch 18 iteration 1300: 0.28081434965133667
# loss in epoch 18 iteration 1400: 0.21814337372779846
# loss in epoch 18 iteration 1500: 0.18661226332187653
# loss in epoch 18 iteration 1600: 0.2217273712158203
# loss in epoch 18 iteration 1700: 0.24161797761917114
# loss in epoch 18 iteration 1800: 0.2718323767185211
# loss in epoch 18 iteration 1900: 0.24926063418388367
# loss in epoch 18 iteration 2000: 0.28143951296806335
# loss in epoch 18 iteration 2100: 0.2247650921344757
# loss in epoch 18 iteration 2200: 0.25498268008232117
# loss in epoch 18 iteration 2300: 0.25064703822135925
# loss in epoch 18 iteration 2400: 0.21790853142738342
# loss in epoch 18 iteration 2500: 0.30340999364852905
# loss in epoch 18 iteration 2600: 0.23772092163562775
# loss in epoch 18 iteration 2700: 0.2564389407634735
# loss in epoch 18 iteration 2800: 0.2671881914138794
# loss in epoch 18 iteration 2900: 0.30633464455604553
# loss in epoch 18 iteration 3000: 0.26204243302345276
# loss in epoch 18 iteration 3100: 0.2505609691143036
# loss in epoch 18 iteration 3200: 0.2618175148963928
# loss in epoch 18 iteration 3300: 0.2253665030002594
# loss in epoch 18 iteration 3400: 0.2611922025680542
# loss in epoch 18 iteration 3500: 0.28558921813964844
# loss in epoch 18 iteration 3600: 0.25796690583229065
# loss in epoch 18 iteration 3700: 0.22046485543251038
# loss in epoch 18 iteration 3800: 0.21901792287826538
# loss in epoch 18 iteration 3900: 0.2736075818538666
# loss in epoch 18 iteration 4000: 0.26195216178894043
# loss in epoch 18 iteration 4100: 0.1941101849079132
# loss in epoch 19 iteration 0: 0.2556873857975006
# loss in epoch 19 iteration 100: 0.2509254813194275
# loss in epoch 19 iteration 200: 0.1967872530221939
# loss in epoch 19 iteration 300: 0.24039283394813538
# loss in epoch 19 iteration 400: 0.26612067222595215
# loss in epoch 19 iteration 500: 0.2741466760635376
# loss in epoch 19 iteration 600: 0.26388970017433167
# loss in epoch 19 iteration 700: 0.2925376296043396
# loss in epoch 19 iteration 800: 0.2652773857116699
# loss in epoch 19 iteration 900: 0.2372545301914215
# loss in epoch 19 iteration 1000: 0.27030378580093384
# loss in epoch 19 iteration 1100: 0.21311698853969574
# loss in epoch 19 iteration 1200: 0.2461954951286316
# loss in epoch 19 iteration 1300: 0.2768377959728241
# loss in epoch 19 iteration 1400: 0.2511732876300812
# loss in epoch 19 iteration 1500: 0.3049848973751068
# loss in epoch 19 iteration 1600: 0.24042800068855286
# loss in epoch 19 iteration 1700: 0.2291094809770584
# loss in epoch 19 iteration 1800: 0.2902793884277344
# loss in epoch 19 iteration 1900: 0.24968068301677704
# loss in epoch 19 iteration 2000: 0.23596185445785522
# loss in epoch 19 iteration 2100: 0.2682679295539856
# loss in epoch 19 iteration 2200: 0.22882702946662903
# loss in epoch 19 iteration 2300: 0.2024042010307312
# loss in epoch 19 iteration 2400: 0.21001413464546204
# loss in epoch 19 iteration 2500: 0.22867992520332336
# loss in epoch 19 iteration 2600: 0.26391351222991943
# loss in epoch 19 iteration 2700: 0.27008742094039917
# loss in epoch 19 iteration 2800: 0.20859584212303162
# loss in epoch 19 iteration 2900: 0.29687508940696716
# loss in epoch 19 iteration 3000: 0.269772469997406
# loss in epoch 19 iteration 3100: 0.23295018076896667
# loss in epoch 19 iteration 3200: 0.22791393101215363
# loss in epoch 19 iteration 3300: 0.25154584646224976
# loss in epoch 19 iteration 3400: 0.22174754738807678
# loss in epoch 19 iteration 3500: 0.2631635069847107
# loss in epoch 19 iteration 3600: 0.22287774085998535
# loss in epoch 19 iteration 3700: 0.19714593887329102
# loss in epoch 19 iteration 3800: 0.19262155890464783
# loss in epoch 19 iteration 3900: 0.2477674037218094
# loss in epoch 19 iteration 4000: 0.21427465975284576
# loss in epoch 19 iteration 4100: 0.25167790055274963
# loss in epoch 20 iteration 0: 0.24781319499015808
# loss in epoch 20 iteration 100: 0.22582101821899414
# loss in epoch 20 iteration 200: 0.2661021053791046
# loss in epoch 20 iteration 300: 0.22792747616767883
# loss in epoch 20 iteration 400: 0.25809478759765625
# loss in epoch 20 iteration 500: 0.24135491251945496
# loss in epoch 20 iteration 600: 0.2567349970340729
# loss in epoch 20 iteration 700: 0.2207024097442627
# loss in epoch 20 iteration 800: 0.2863822281360626
# loss in epoch 20 iteration 900: 0.25280171632766724
# loss in epoch 20 iteration 1000: 0.20906193554401398
# loss in epoch 20 iteration 1100: 0.21491798758506775
# loss in epoch 20 iteration 1200: 0.22199660539627075
# loss in epoch 20 iteration 1300: 0.25633135437965393
# loss in epoch 20 iteration 1400: 0.2505992650985718
# loss in epoch 20 iteration 1500: 0.25999823212623596
# loss in epoch 20 iteration 1600: 0.266029417514801
# loss in epoch 20 iteration 1700: 0.21935543417930603
# loss in epoch 20 iteration 1800: 0.21503856778144836
# loss in epoch 20 iteration 1900: 0.250522255897522
# loss in epoch 20 iteration 2000: 0.23776909708976746
# loss in epoch 20 iteration 2100: 0.22828376293182373
# loss in epoch 20 iteration 2200: 0.2480083703994751
# loss in epoch 20 iteration 2300: 0.2084755301475525
# loss in epoch 20 iteration 2400: 0.21742653846740723
# loss in epoch 20 iteration 2500: 0.2571284770965576
# loss in epoch 20 iteration 2600: 0.20749692618846893
# loss in epoch 20 iteration 2700: 0.2333633303642273
# loss in epoch 20 iteration 2800: 0.26356300711631775
# loss in epoch 20 iteration 2900: 0.2427104264497757
# loss in epoch 20 iteration 3000: 0.23756787180900574
# loss in epoch 20 iteration 3100: 0.2703830599784851
# loss in epoch 20 iteration 3200: 0.2066056728363037
# loss in epoch 20 iteration 3300: 0.224062979221344
# loss in epoch 20 iteration 3400: 0.2450171262025833
# loss in epoch 20 iteration 3500: 0.2020418643951416
# loss in epoch 20 iteration 3600: 0.21922725439071655
# loss in epoch 20 iteration 3700: 0.2128087282180786
# loss in epoch 20 iteration 3800: 0.2500627338886261
# loss in epoch 20 iteration 3900: 0.24788028001785278
# loss in epoch 20 iteration 4000: 0.2114526927471161
# loss in epoch 20 iteration 4100: 0.2691945731639862
# loss in epoch 21 iteration 0: 0.23674128949642181
# loss in epoch 21 iteration 100: 0.25236186385154724
# loss in epoch 21 iteration 200: 0.24104389548301697
# loss in epoch 21 iteration 300: 0.21400706470012665
# loss in epoch 21 iteration 400: 0.2346261739730835
# loss in epoch 21 iteration 500: 0.205005943775177
# loss in epoch 21 iteration 600: 0.2295798808336258
# loss in epoch 21 iteration 700: 0.2255449891090393
# loss in epoch 21 iteration 800: 0.24735605716705322
# loss in epoch 21 iteration 900: 0.2342347353696823
# loss in epoch 21 iteration 1000: 0.24846860766410828
# loss in epoch 21 iteration 1100: 0.2287752330303192
# loss in epoch 21 iteration 1200: 0.2144688367843628
# loss in epoch 21 iteration 1300: 0.21001842617988586
# loss in epoch 21 iteration 1400: 0.2684290409088135
# loss in epoch 21 iteration 1500: 0.2441646158695221
# loss in epoch 21 iteration 1600: 0.27907195687294006
# loss in epoch 21 iteration 1700: 0.1833016276359558
# loss in epoch 21 iteration 1800: 0.2187136560678482
# loss in epoch 21 iteration 1900: 0.2620924711227417
# loss in epoch 21 iteration 2000: 0.22372911870479584
# loss in epoch 21 iteration 2100: 0.2024620622396469
# loss in epoch 21 iteration 2200: 0.25726383924484253
# loss in epoch 21 iteration 2300: 0.24676036834716797
# loss in epoch 21 iteration 2400: 0.21228986978530884
# loss in epoch 21 iteration 2500: 0.23792210221290588
# loss in epoch 21 iteration 2600: 0.24134668707847595
# loss in epoch 21 iteration 2700: 0.20997318625450134
# loss in epoch 21 iteration 2800: 0.2019769549369812
# loss in epoch 21 iteration 2900: 0.17924904823303223
# loss in epoch 21 iteration 3000: 0.2156735360622406
# loss in epoch 21 iteration 3100: 0.23765385150909424
# loss in epoch 21 iteration 3200: 0.22841624915599823
# loss in epoch 21 iteration 3300: 0.2335871458053589
# loss in epoch 21 iteration 3400: 0.24122735857963562
# loss in epoch 21 iteration 3500: 0.21231764554977417
# loss in epoch 21 iteration 3600: 0.1924048811197281
# loss in epoch 21 iteration 3700: 0.2212454378604889
# loss in epoch 21 iteration 3800: 0.22111159563064575
# loss in epoch 21 iteration 3900: 0.21297994256019592
# loss in epoch 21 iteration 4000: 0.2431936264038086
# loss in epoch 21 iteration 4100: 0.23787549138069153
# loss in epoch 22 iteration 0: 0.23151293396949768
# loss in epoch 22 iteration 100: 0.1987411230802536
# loss in epoch 22 iteration 200: 0.21553103625774384
# loss in epoch 22 iteration 300: 0.24244970083236694
# loss in epoch 22 iteration 400: 0.25315573811531067
# loss in epoch 22 iteration 500: 0.2573181092739105
# loss in epoch 22 iteration 600: 0.22150953114032745
# loss in epoch 22 iteration 700: 0.25346386432647705
# loss in epoch 22 iteration 800: 0.26267319917678833
# loss in epoch 22 iteration 900: 0.24313423037528992
# loss in epoch 22 iteration 1000: 0.22374102473258972
# loss in epoch 22 iteration 1100: 0.255208283662796
# loss in epoch 22 iteration 1200: 0.25710222125053406
# loss in epoch 22 iteration 1300: 0.24595928192138672
# loss in epoch 22 iteration 1400: 0.21859240531921387
# loss in epoch 22 iteration 1500: 0.22126518189907074
# loss in epoch 22 iteration 1600: 0.2227124273777008
# loss in epoch 22 iteration 1700: 0.21657371520996094
# loss in epoch 22 iteration 1800: 0.25117984414100647
# loss in epoch 22 iteration 1900: 0.23400717973709106
# loss in epoch 22 iteration 2000: 0.24349012970924377
# loss in epoch 22 iteration 2100: 0.2422322779893875
# loss in epoch 22 iteration 2200: 0.23847666382789612
# loss in epoch 22 iteration 2300: 0.21136076748371124
# loss in epoch 22 iteration 2400: 0.23313650488853455
# loss in epoch 22 iteration 2500: 0.23432165384292603
# loss in epoch 22 iteration 2600: 0.2206202894449234
# loss in epoch 22 iteration 2700: 0.24858099222183228
# loss in epoch 22 iteration 2800: 0.2103099673986435
# loss in epoch 22 iteration 2900: 0.2037121057510376
# loss in epoch 22 iteration 3000: 0.24338191747665405
# loss in epoch 22 iteration 3100: 0.2142285406589508
# loss in epoch 22 iteration 3200: 0.21709854900836945
# loss in epoch 22 iteration 3300: 0.25997886061668396
# loss in epoch 22 iteration 3400: 0.2261183112859726
# loss in epoch 22 iteration 3500: 0.26039937138557434
# loss in epoch 22 iteration 3600: 0.22798341512680054
# loss in epoch 22 iteration 3700: 0.19041034579277039
# loss in epoch 22 iteration 3800: 0.22030504047870636
# loss in epoch 22 iteration 3900: 0.2382795363664627
# loss in epoch 22 iteration 4000: 0.18797554075717926
# loss in epoch 22 iteration 4100: 0.25091245770454407
# loss in epoch 23 iteration 0: 0.19663244485855103
# loss in epoch 23 iteration 100: 0.2329443097114563
# loss in epoch 23 iteration 200: 0.23784342408180237
# loss in epoch 23 iteration 300: 0.20990517735481262
# loss in epoch 23 iteration 400: 0.21177521347999573
# loss in epoch 23 iteration 500: 0.2158949077129364
# ...
# loss in epoch 23 iteration 3100: 0.21428024768829346
# loss in epoch 23 iteration 3200: 0.23454062640666962
# loss in epoch 23 iteration 3300: 0.2005009949207306
# loss in epoch 23 iteration 3400: 0.22775408625602722
# loss in epoch 23 iteration 3500: 0.21641594171524048
# loss in epoch 23 iteration 3600: 0.2279236912727356
# loss in epoch 23 iteration 3700: 0.20129218697547913
# loss in epoch 23 iteration 3800: 0.22191885113716125
# loss in epoch 23 iteration 3900: 0.22441300749778748
# loss in epoch 23 iteration 4000: 0.2068718671798706
# loss in epoch 23 iteration 4100: 0.21763238310813904
# loss in epoch 24 iteration 0: 0.23841725289821625
# loss in epoch 24 iteration 100: 0.2429327368736267
# loss in epoch 24 iteration 200: 0.20416614413261414
# loss in epoch 24 iteration 300: 0.18612802028656006
# loss in epoch 24 iteration 400: 0.21288403868675232
# loss in epoch 24 iteration 500: 0.2072385996580124
# loss in epoch 24 iteration 600: 0.21796640753746033
# loss in epoch 24 iteration 700: 0.22838440537452698
# loss in epoch 24 iteration 800: 0.21069204807281494
# loss in epoch 24 iteration 900: 0.22099287807941437
# loss in epoch 24 iteration 1000: 0.20395085215568542
# loss in epoch 24 iteration 1100: 0.21693706512451172
# loss in epoch 24 iteration 1200: 0.20677751302719116
# loss in epoch 24 iteration 1300: 0.25235089659690857
# loss in epoch 24 iteration 1400: 0.20911909639835358
# loss in epoch 24 iteration 1500: 0.22002379596233368
# loss in epoch 24 iteration 1600: 0.18126627802848816
# loss in epoch 24 iteration 1700: 0.2704775035381317
# loss in epoch 24 iteration 1800: 0.24150073528289795
# loss in epoch 24 iteration 1900: 0.24582292139530182
# loss in epoch 24 iteration 2000: 0.19090808928012848
# loss in epoch 24 iteration 2100: 0.18563716113567352
# loss in epoch 24 iteration 2200: 0.22383847832679749
# loss in epoch 24 iteration 2300: 0.2157043069601059
# loss in epoch 24 iteration 2400: 0.22685226798057556
# loss in epoch 24 iteration 2500: 0.21744132041931152
# loss in epoch 24 iteration 2600: 0.20536158978939056
# loss in epoch 24 iteration 2700: 0.22057129442691803
# loss in epoch 24 iteration 2800: 0.24171754717826843
# loss in epoch 24 iteration 2900: 0.22398264706134796
# loss in epoch 24 iteration 3000: 0.21071913838386536
# loss in epoch 24 iteration 3100: 0.20189118385314941
# loss in epoch 24 iteration 3200: 0.22639259696006775
# loss in epoch 24 iteration 3300: 0.191884383559227
# loss in epoch 24 iteration 3400: 0.21259409189224243
# loss in epoch 24 iteration 3500: 0.2347896844148636
# loss in epoch 24 iteration 3600: 0.20726686716079712
# loss in epoch 24 iteration 3700: 0.21326056122779846
# loss in epoch 24 iteration 3800: 0.1929684728384018
# loss in epoch 24 iteration 3900: 0.20685377717018127
# loss in epoch 24 iteration 4000: 0.20284639298915863
# loss in epoch 24 iteration 4100: 0.23818619549274445
# loss in epoch 25 iteration 0: 0.21393564343452454
# loss in epoch 25 iteration 100: 0.21105073392391205
# loss in epoch 25 iteration 200: 0.21542659401893616
# loss in epoch 25 iteration 300: 0.2347797453403473
# loss in epoch 25 iteration 400: 0.1932682991027832
# loss in epoch 25 iteration 500: 0.20802775025367737
# loss in epoch 25 iteration 600: 0.2024235874414444
# loss in epoch 25 iteration 700: 0.21884459257125854
# loss in epoch 25 iteration 800: 0.19902512431144714
# loss in epoch 25 iteration 900: 0.1888260394334793
# loss in epoch 25 iteration 1000: 0.21922066807746887
# loss in epoch 25 iteration 1100: 0.22896745800971985
# loss in epoch 25 iteration 1200: 0.2219793200492859
# loss in epoch 25 iteration 1300: 0.23470532894134521
# loss in epoch 25 iteration 1400: 0.19586002826690674
# loss in epoch 25 iteration 1500: 0.22475607693195343
# loss in epoch 25 iteration 1600: 0.24183498322963715
# loss in epoch 25 iteration 1700: 0.2136058658361435
# loss in epoch 25 iteration 1800: 0.21121439337730408
# loss in epoch 25 iteration 1900: 0.22022631764411926
# loss in epoch 25 iteration 2000: 0.1938348114490509
# loss in epoch 25 iteration 2100: 0.20970949530601501
# loss in epoch 25 iteration 2200: 0.24075260758399963
# loss in epoch 25 iteration 2300: 0.23902806639671326
# loss in epoch 25 iteration 2400: 0.20777887105941772
# loss in epoch 25 iteration 2500: 0.18706509470939636
# loss in epoch 25 iteration 2600: 0.2116014063358307
# loss in epoch 25 iteration 2700: 0.2090100795030594
# loss in epoch 25 iteration 2800: 0.20352321863174438
# loss in epoch 25 iteration 2900: 0.2369728535413742
# loss in epoch 25 iteration 3000: 0.20276609063148499
# loss in epoch 25 iteration 3100: 0.22478792071342468
# loss in epoch 25 iteration 3200: 0.20027825236320496
# loss in epoch 25 iteration 3300: 0.2402624487876892
# loss in epoch 25 iteration 3400: 0.2142295241355896
# loss in epoch 25 iteration 3500: 0.1825116127729416
# loss in epoch 25 iteration 3600: 0.19681131839752197
# loss in epoch 25 iteration 3700: 0.2016478180885315
# loss in epoch 25 iteration 3800: 0.205974280834198
# loss in epoch 25 iteration 3900: 0.19911238551139832
# loss in epoch 25 iteration 4000: 0.19691702723503113
# loss in epoch 25 iteration 4100: 0.19500204920768738
# loss in epoch 26 iteration 0: 0.18466022610664368
# loss in epoch 26 iteration 100: 0.21690422296524048
# loss in epoch 26 iteration 200: 0.20155975222587585
# loss in epoch 26 iteration 300: 0.1894254833459854
# loss in epoch 26 iteration 400: 0.17597919702529907
# loss in epoch 26 iteration 500: 0.232892245054245
# loss in epoch 26 iteration 600: 0.18727917969226837
# loss in epoch 26 iteration 700: 0.22919945418834686
# loss in epoch 26 iteration 800: 0.18846134841442108
# loss in epoch 26 iteration 900: 0.23331508040428162
# loss in epoch 26 iteration 1000: 0.2196747362613678
# loss in epoch 26 iteration 1100: 0.19717487692832947
# loss in epoch 26 iteration 1200: 0.19119402766227722
# loss in epoch 26 iteration 1300: 0.2293996810913086
# loss in epoch 26 iteration 1400: 0.1832655966281891
# loss in epoch 26 iteration 1500: 0.1873348355293274
# loss in epoch 26 iteration 1600: 0.21206429600715637
# loss in epoch 26 iteration 1700: 0.19842684268951416
# loss in epoch 26 iteration 1800: 0.22717925906181335
# loss in epoch 26 iteration 1900: 0.19653037190437317
# loss in epoch 26 iteration 2000: 0.19855239987373352
# loss in epoch 26 iteration 2100: 0.20180398225784302
# loss in epoch 26 iteration 2200: 0.20211562514305115
# loss in epoch 26 iteration 2300: 0.19143611192703247
# loss in epoch 26 iteration 2400: 0.24588918685913086
# loss in epoch 26 iteration 2500: 0.22579436004161835
# loss in epoch 26 iteration 2600: 0.2216579169034958
# loss in epoch 26 iteration 2700: 0.18311862647533417
# loss in epoch 26 iteration 2800: 0.19050204753875732
# loss in epoch 26 iteration 2900: 0.1889735758304596
# loss in epoch 26 iteration 3000: 0.20932021737098694
# loss in epoch 26 iteration 3100: 0.2072632908821106
# loss in epoch 26 iteration 3200: 0.24308176338672638
# loss in epoch 26 iteration 3300: 0.23260293900966644
# loss in epoch 26 iteration 3400: 0.21778671443462372
# loss in epoch 26 iteration 3500: 0.19742730259895325
# loss in epoch 26 iteration 3600: 0.2316470891237259
# loss in epoch 26 iteration 3700: 0.18524810671806335
# loss in epoch 26 iteration 3800: 0.1810404658317566
# loss in epoch 26 iteration 3900: 0.21662694215774536
# loss in epoch 26 iteration 4000: 0.21844922006130219
# loss in epoch 26 iteration 4100: 0.20483925938606262
# loss in epoch 27 iteration 0: 0.19971135258674622
# loss in epoch 27 iteration 100: 0.22060006856918335
# loss in epoch 27 iteration 200: 0.22349892556667328
# loss in epoch 27 iteration 300: 0.1824948936700821
# loss in epoch 27 iteration 400: 0.19779035449028015
# loss in epoch 27 iteration 500: 0.17186599969863892
# loss in epoch 27 iteration 600: 0.1929110884666443
# loss in epoch 27 iteration 700: 0.19835829734802246
# loss in epoch 27 iteration 800: 0.22553400695323944
# loss in epoch 27 iteration 900: 0.198135107755661
# loss in epoch 27 iteration 1000: 0.21402719616889954
# loss in epoch 27 iteration 1100: 0.1826731264591217
# loss in epoch 27 iteration 1200: 0.20799419283866882
# loss in epoch 27 iteration 1300: 0.16196966171264648
# loss in epoch 27 iteration 1400: 0.17238618433475494
# loss in epoch 27 iteration 1500: 0.18474724888801575
# loss in epoch 27 iteration 1600: 0.19350019097328186
# loss in epoch 27 iteration 1700: 0.2281736135482788
# loss in epoch 27 iteration 1800: 0.24164438247680664
# loss in epoch 27 iteration 1900: 0.2362898886203766
# loss in epoch 27 iteration 2000: 0.21153241395950317
# loss in epoch 27 iteration 2100: 0.20108777284622192
# loss in epoch 27 iteration 2200: 0.21254780888557434
# loss in epoch 27 iteration 2300: 0.19204969704151154
# loss in epoch 27 iteration 2400: 0.16777403652668
# loss in epoch 27 iteration 2500: 0.21719437837600708
# loss in epoch 27 iteration 2600: 0.14996671676635742
# loss in epoch 27 iteration 2700: 0.17502941191196442
# loss in epoch 27 iteration 2800: 0.17736588418483734
# loss in epoch 27 iteration 2900: 0.18063850700855255
# loss in epoch 27 iteration 3000: 0.21690282225608826
# loss in epoch 27 iteration 3100: 0.1664271354675293
# loss in epoch 27 iteration 3200: 0.2315065860748291
# loss in epoch 27 iteration 3300: 0.2048703134059906
# loss in epoch 27 iteration 3400: 0.17910534143447876
# loss in epoch 27 iteration 3500: 0.19089218974113464
# loss in epoch 27 iteration 3600: 0.16883708536624908
# loss in epoch 27 iteration 3700: 0.19595780968666077
# loss in epoch 27 iteration 3800: 0.19544102251529694
# loss in epoch 27 iteration 3900: 0.2220742255449295
# loss in epoch 27 iteration 4000: 0.22704796493053436
# loss in epoch 27 iteration 4100: 0.21996745467185974
# loss in epoch 28 iteration 0: 0.1907854527235031
# loss in epoch 28 iteration 100: 0.1954406201839447
# loss in epoch 28 iteration 200: 0.19868426024913788
# loss in epoch 28 iteration 300: 0.18583551049232483
# loss in epoch 28 iteration 400: 0.20971037447452545
# loss in epoch 28 iteration 500: 0.21599023044109344
# loss in epoch 28 iteration 600: 0.19024509191513062
# loss in epoch 28 iteration 700: 0.22279523313045502
# loss in epoch 28 iteration 800: 0.20893287658691406
# loss in epoch 28 iteration 900: 0.20017197728157043
# loss in epoch 28 iteration 1000: 0.20646266639232635
# loss in epoch 28 iteration 1100: 0.17018896341323853
# loss in epoch 28 iteration 1200: 0.20092959702014923
# loss in epoch 28 iteration 1300: 0.18996372818946838
# loss in epoch 28 iteration 1400: 0.18502271175384521
# loss in epoch 28 iteration 1500: 0.187282532453537
# loss in epoch 28 iteration 1600: 0.17448261380195618
# loss in epoch 28 iteration 1700: 0.22946575284004211
# loss in epoch 28 iteration 1800: 0.21947738528251648
# loss in epoch 28 iteration 1900: 0.17398780584335327
# loss in epoch 28 iteration 2000: 0.1909470558166504
# loss in epoch 28 iteration 2100: 0.18824897706508636
# loss in epoch 28 iteration 2200: 0.1828465312719345
# loss in epoch 28 iteration 2300: 0.22175399959087372
# loss in epoch 28 iteration 2400: 0.270214319229126
# loss in epoch 28 iteration 2500: 0.1860814392566681
# loss in epoch 28 iteration 2600: 0.1819528043270111
# loss in epoch 28 iteration 2700: 0.24987611174583435
# loss in epoch 28 iteration 2800: 0.21966521441936493
# loss in epoch 28 iteration 2900: 0.23514758050441742
# loss in epoch 28 iteration 3000: 0.2290896773338318
# loss in epoch 28 iteration 3100: 0.19637063145637512
# loss in epoch 28 iteration 3200: 0.2013234794139862
# loss in epoch 28 iteration 3300: 0.2000032663345337
# loss in epoch 28 iteration 3400: 0.17588619887828827
# loss in epoch 28 iteration 3500: 0.17919781804084778
# loss in epoch 28 iteration 3600: 0.16381433606147766
# loss in epoch 28 iteration 3700: 0.21330738067626953
# loss in epoch 28 iteration 3800: 0.21607168018817902
# loss in epoch 28 iteration 3900: 0.21312730014324188
# loss in epoch 28 iteration 4000: 0.23748785257339478
# loss in epoch 28 iteration 4100: 0.21173924207687378
# loss in epoch 29 iteration 0: 0.20159319043159485
# loss in epoch 29 iteration 100: 0.19502395391464233
# loss in epoch 29 iteration 200: 0.19122442603111267
# loss in epoch 29 iteration 300: 0.2022005021572113
# loss in epoch 29 iteration 400: 0.16197983920574188
# loss in epoch 29 iteration 500: 0.17707671225070953
# loss in epoch 29 iteration 600: 0.1817166954278946
# loss in epoch 29 iteration 700: 0.1715620458126068
# loss in epoch 29 iteration 800: 0.1843852549791336
# loss in epoch 29 iteration 900: 0.20144619047641754
# loss in epoch 29 iteration 1000: 0.18202495574951172
# loss in epoch 29 iteration 1100: 0.16289104521274567
# loss in epoch 29 iteration 1200: 0.18205207586288452
# loss in epoch 29 iteration 1300: 0.24632158875465393
# loss in epoch 29 iteration 1400: 0.2120484709739685
# loss in epoch 29 iteration 1500: 0.1801796853542328
# loss in epoch 29 iteration 1600: 0.21420113742351532
# loss in epoch 29 iteration 1700: 0.1826050877571106
# loss in epoch 29 iteration 1800: 0.17880049347877502
# loss in epoch 29 iteration 1900: 0.20567499101161957
# loss in epoch 29 iteration 2000: 0.23854108154773712
# loss in epoch 29 iteration 2100: 0.21230076253414154
# loss in epoch 29 iteration 2200: 0.18341109156608582
# loss in epoch 29 iteration 2300: 0.18157163262367249
# loss in epoch 29 iteration 2400: 0.21614086627960205
# loss in epoch 29 iteration 2500: 0.2258813977241516
# loss in epoch 29 iteration 2600: 0.21555763483047485
# loss in epoch 29 iteration 2700: 0.19640889763832092
# loss in epoch 29 iteration 2800: 0.1985621452331543
# loss in epoch 29 iteration 2900: 0.19658228754997253
# loss in epoch 29 iteration 3000: 0.18053746223449707
# loss in epoch 29 iteration 3100: 0.17110368609428406
# loss in epoch 29 iteration 3200: 0.19827543199062347
# loss in epoch 29 iteration 3300: 0.183619424700737
# loss in epoch 29 iteration 3400: 0.20311301946640015
# loss in epoch 29 iteration 3500: 0.22101286053657532
# loss in epoch 29 iteration 3600: 0.19765663146972656
# loss in epoch 29 iteration 3700: 0.20328736305236816
# loss in epoch 29 iteration 3800: 0.21069811284542084
# loss in epoch 29 iteration 3900: 0.2013704478740692
# loss in epoch 29 iteration 4000: 0.16946227848529816
# loss in epoch 29 iteration 4100: 0.19047284126281738
# loss in epoch 30 iteration 0: 0.22653555870056152
# loss in epoch 30 iteration 100: 0.1881493479013443
# loss in epoch 30 iteration 200: 0.1810522973537445
# loss in epoch 30 iteration 300: 0.19974392652511597
# loss in epoch 30 iteration 400: 0.14297492802143097
# loss in epoch 30 iteration 500: 0.18704374134540558
# loss in epoch 30 iteration 600: 0.20766335725784302
# loss in epoch 30 iteration 700: 0.21414929628372192
# loss in epoch 30 iteration 800: 0.17666314542293549
# loss in epoch 30 iteration 900: 0.16078335046768188
# loss in epoch 30 iteration 1000: 0.1914958655834198
# loss in epoch 30 iteration 1100: 0.21729975938796997
# loss in epoch 30 iteration 1200: 0.19359612464904785
# loss in epoch 30 iteration 1300: 0.15778420865535736
# loss in epoch 30 iteration 1400: 0.2089737057685852
# loss in epoch 30 iteration 1500: 0.15217700600624084
# loss in epoch 30 iteration 1600: 0.16046366095542908
# loss in epoch 30 iteration 1700: 0.15014050900936127
# loss in epoch 30 iteration 1800: 0.21528545022010803
# loss in epoch 30 iteration 1900: 0.233418270945549
# loss in epoch 30 iteration 2000: 0.18027141690254211
# loss in epoch 30 iteration 2100: 0.15400612354278564
# loss in epoch 30 iteration 2200: 0.20237235724925995
# loss in epoch 30 iteration 2300: 0.2094823122024536
# loss in epoch 30 iteration 2400: 0.19243913888931274
# loss in epoch 30 iteration 2500: 0.18831214308738708
# loss in epoch 30 iteration 2600: 0.19785664975643158
# loss in epoch 30 iteration 2700: 0.20983591675758362
# loss in epoch 30 iteration 2800: 0.1859942376613617
# loss in epoch 30 iteration 2900: 0.18139612674713135
# loss in epoch 30 iteration 3000: 0.17213235795497894
# loss in epoch 30 iteration 3100: 0.1750355064868927
# loss in epoch 30 iteration 3200: 0.16605956852436066
# loss in epoch 30 iteration 3300: 0.16691257059574127
# loss in epoch 30 iteration 3400: 0.20250117778778076
# loss in epoch 30 iteration 3500: 0.1851150393486023
# loss in epoch 30 iteration 3600: 0.17432165145874023
# loss in epoch 30 iteration 3700: 0.1735689789056778
# loss in epoch 30 iteration 3800: 0.21831578016281128
# loss in epoch 30 iteration 3900: 0.20844033360481262
# loss in epoch 30 iteration 4000: 0.18228796124458313
# loss in epoch 30 iteration 4100: 0.20395208895206451
# Done

# %%
model.load_state_dict(torch.load("/content/drive/Shareddrives/RecSys/MeLi/checkpoints/SASRec.epoch=50.lr=0.001.layer=3.head=1.hidden=64.maxlen=30.pth"))
# Out:
# <All keys matched successfully>

# %%
model.eval()
t_test = evaluate(model, dataset, args)
print('test (NDCG@10: %.4f, HR@10: %.4f)' % (t_test[0], t_test[1]))
# Out:
# ..................................................................................test (NDCG@10: 0.7270, HR@10: 0.8654)

# %%
model.eval()
dataset_test = data_partition('/content/drive/Shareddrives/RecSys/Datasets/mercadolibre_test.txt', 'xd')

# %%
import pickle

with open('/content/drive/Shareddrives/RecSys/MeLi/pickles/baseline231_50.pkl', 'rb') as f:
   predictions = pickle.load(f)

# %%
len(predictions)
# Out:
# 177070

# %%
u_problems = predict(model, dataset_test, args, itemnum, f'/content/SASRec.epoch={args.num_epochs}.lr={args.lr}.layer={args.num_blocks}.head={args.num_heads}.hidden={args.hidden_units}.maxlen={args.maxlen}with_predictions.csv', final_index, final_reindex, predictions)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=177070.0), HTML(value='')))
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1047106 no esta en reindex
# Item 241469 no esta en reindex
# Item 1632751 no esta en reindex
# Item 1873574 no esta en reindex
# Item 1545772 no esta en reindex
# Item 403558 no esta en reindex
# Item 246833 no esta en reindex
# Item 915201 no esta en reindex
# Item 1047106 no esta en reindex
# Item 2086215 no esta en reindex
# Item 403558 no esta en reindex
# Item 493812 no esta en reindex
# Item 1800012 no esta en reindex
# Item 230235 no esta en reindex
# Item 749818 no esta en reindex
# Item 417263 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1492931 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 16746 no esta en reindex
# Item 435484 no esta en reindex
# Item 512644 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1707526 no esta en reindex
# Item 1881931 no esta en reindex
# Item 1276876 no esta en reindex
# Item 417263 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1853773 no esta en reindex
# Item 291823 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1551358 no esta en reindex
# Item 625267 no esta en reindex
# Item 1117558 no esta en reindex
# Item 1656284 no esta en reindex
# Item 932580 no esta en reindex
# Item 812655 no esta en reindex
# Item 480556 no esta en reindex
# Item 812655 no esta en reindex
# Item 53589 no esta en reindex
# Item 1986189 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1358048 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1656284 no esta en reindex
# Item 625267 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1276876 no esta en reindex
# Item 417263 no esta en reindex
# Item 1506349 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1551358 no esta en reindex
# Item 533417 no esta en reindex
# Item 753345 no esta en reindex
# Item 915201 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 812655 no esta en reindex
# Item 1455545 no esta en reindex
# Item 812655 no esta en reindex
# Item 178889 no esta en reindex
# Item 178889 no esta en reindex
# Item 1276876 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1551358 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1047106 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1054592 no esta en reindex
# Item 1580278 no esta en reindex
# Item 2100622 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1628486 no esta en reindex
# Item 363739 no esta en reindex
# Item 636862 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 288453 no esta en reindex
# Item 592564 no esta en reindex
# Item 625267 no esta en reindex
# Item 194713 no esta en reindex
# Item 1551358 no esta en reindex
# Item 235617 no esta en reindex
# Item 1927909 no esta en reindex
# Item 812655 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 2086215 no esta en reindex
# Item 588684 no esta en reindex
# Item 636862 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 753345 no esta en reindex
# Item 932580 no esta en reindex
# Item 1924594 no esta en reindex
# Item 749818 no esta en reindex
# Item 1276876 no esta en reindex
# Item 1358048 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1873574 no esta en reindex
# Item 1701695 no esta en reindex
# Item 932580 no esta en reindex
# Item 1986189 no esta en reindex
# Item 1580278 no esta en reindex
# Item 1927909 no esta en reindex
# Item 915201 no esta en reindex
# Item 126450 no esta en reindex
# Item 666855 no esta en reindex
# Item 1436780 no esta en reindex
# Item 812655 no esta en reindex
# Item 1632751 no esta en reindex
# Item 1047106 no esta en reindex
# Item 709763 no esta en reindex
# Item 1611218 no esta en reindex
# Item 2086215 no esta en reindex
# Item 320794 no esta en reindex
# Item 625267 no esta en reindex
# Item 288453 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1707526 no esta en reindex
# Item 827401 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1100438 no esta en reindex
# Item 636862 no esta en reindex
# Item 492003 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1197205 no esta en reindex
# Item 1457355 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1336882 no esta en reindex
# Item 1082628 no esta en reindex
# Item 932580 no esta en reindex
# Item 53589 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 178889 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 636862 no esta en reindex
# Item 126450 no esta en reindex
# Item 753345 no esta en reindex
# Item 625267 no esta en reindex
# Item 1457355 no esta en reindex
# Item 820192 no esta en reindex
# Item 235617 no esta en reindex
# Item 224174 no esta en reindex
# Item 1358048 no esta en reindex
# Item 1276876 no esta en reindex
# Item 2016223 no esta en reindex
# Item 241469 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1521240 no esta en reindex
# Item 512644 no esta en reindex
# Item 178889 no esta en reindex
# Item 1024293 no esta en reindex
# Item 2016223 no esta en reindex
# Item 363739 no esta en reindex
# Item 1289288 no esta en reindex
# Item 753475 no esta en reindex
# Item 837923 no esta en reindex
# Item 480556 no esta en reindex
# Item 812655 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1283781 no esta en reindex
# Item 1884438 no esta en reindex
# Item 915633 no esta en reindex
# Item 2039233 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 1570916 no esta en reindex
# Item 1218398 no esta en reindex
# Item 304222 no esta en reindex
# Item 291823 no esta en reindex
# Item 625267 no esta en reindex
# Item 1455545 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1358048 no esta en reindex
# Item 946018 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 493812 no esta en reindex
# Item 1146005 no esta en reindex
# Item 636862 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1047106 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1337152 no esta en reindex
# Item 24912 no esta en reindex
# Item 1713558 no esta en reindex
# Item 512644 no esta en reindex
# Item 492003 no esta en reindex
# Item 154147 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1580278 no esta en reindex
# Item 753345 no esta en reindex
# Item 1271327 no esta en reindex
# Item 1628486 no esta en reindex
# Item 812655 no esta en reindex
# Item 837923 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1632751 no esta en reindex
# Item 726348 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1707526 no esta en reindex
# Item 53589 no esta en reindex
# Item 216850 no esta en reindex
# Item 230235 no esta en reindex
# Item 417745 no esta en reindex
# Item 1094533 no esta en reindex
# Item 512644 no esta en reindex
# Item 2039233 no esta en reindex
# Item 812655 no esta en reindex
# Item 2039233 no esta en reindex
# Item 361061 no esta en reindex
# Item 1502354 no esta en reindex
# Item 1047106 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 666855 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1540898 no esta en reindex
# Item 1847546 no esta en reindex
# Item 457352 no esta en reindex
# Item 126450 no esta en reindex
# Item 636862 no esta en reindex
# Item 505481 no esta en reindex
# Item 406438 no esta en reindex
# Item 1540898 no esta en reindex
# Item 1965999 no esta en reindex
# Item 812655 no esta en reindex
# Item 1701695 no esta en reindex
# Item 178889 no esta en reindex
# Item 1580278 no esta en reindex
# Item 1761546 no esta en reindex
# Item 550219 no esta en reindex
# Item 985063 no esta en reindex
# Item 625267 no esta en reindex
# Item 2086215 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 1289288 no esta en reindex
# Item 2039233 no esta en reindex
# Item 912105 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1951168 no esta en reindex
# Item 261612 no esta en reindex
# Item 403558 no esta en reindex
# Item 2086215 no esta en reindex
# Item 636862 no esta en reindex
# Item 2086215 no esta en reindex
# Item 932580 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1006493 no esta en reindex
# Item 53589 no esta en reindex
# Item 837923 no esta en reindex
# Item 417263 no esta en reindex
# Item 1054592 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 1551358 no esta en reindex
# Item 779393 no esta en reindex
# Item 291823 no esta en reindex
# Item 126450 no esta en reindex
# Item 291823 no esta en reindex
# Item 126450 no esta en reindex
# Item 915633 no esta en reindex
# Item 1847546 no esta en reindex
# Item 178889 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1808733 no esta en reindex
# Item 126450 no esta en reindex
# Item 1054592 no esta en reindex
# Item 1707526 no esta en reindex
# Item 1707526 no esta en reindex
# Item 965793 no esta en reindex
# Item 86924 no esta en reindex
# Item 1373402 no esta en reindex
# Item 1276876 no esta en reindex
# Item 1449752 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 16746 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2086215 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 216850 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 1094533 no esta en reindex
# Item 932580 no esta en reindex
# Item 1986189 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1455545 no esta en reindex
# Item 837923 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1873574 no esta en reindex
# Item 625267 no esta en reindex
# Item 1455340 no esta en reindex
# Item 2039233 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 2054695 no esta en reindex
# Item 1285037 no esta en reindex
# Item 363739 no esta en reindex
# Item 379311 no esta en reindex
# Item 2039233 no esta en reindex
# Item 235791 no esta en reindex
# Item 126450 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1628486 no esta en reindex
# Item 786873 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1740636 no esta en reindex
# Item 363739 no esta en reindex
# Item 812655 no esta en reindex
# Item 2088000 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1656284 no esta en reindex
# Item 1358048 no esta en reindex
# Item 2016223 no esta en reindex
# Item 230235 no esta en reindex
# Item 2039233 no esta en reindex
# Item 235791 no esta en reindex
# Item 932580 no esta en reindex
# Item 1992410 no esta en reindex
# Item 512644 no esta en reindex
# Item 235791 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1707867 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1656284 no esta en reindex
# Item 417263 no esta en reindex
# Item 912105 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1100438 no esta en reindex
# Item 53589 no esta en reindex
# Item 1457355 no esta en reindex
# Item 288453 no esta en reindex
# Item 566196 no esta en reindex
# Item 1063701 no esta en reindex
# Item 625267 no esta en reindex
# Item 403558 no esta en reindex
# Item 1455545 no esta en reindex
# Item 827401 no esta en reindex
# Item 709763 no esta en reindex
# Item 1449752 no esta en reindex
# Item 812655 no esta en reindex
# Item 2039233 no esta en reindex
# Item 812655 no esta en reindex
# Item 1873574 no esta en reindex
# Item 1570916 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 113754 no esta en reindex
# Item 1787599 no esta en reindex
# Item 492003 no esta en reindex
# Item 194713 no esta en reindex
# Item 524380 no esta en reindex
# Item 749818 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 1457355 no esta en reindex
# Item 915201 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 1218398 no esta en reindex
# Item 911531 no esta en reindex
# Item 2016223 no esta en reindex
# Item 1054592 no esta en reindex
# Item 2039233 no esta en reindex
# Item 417263 no esta en reindex
# Item 1632751 no esta en reindex
# Item 837923 no esta en reindex
# Item 1047106 no esta en reindex
# Item 304222 no esta en reindex
# Item 53589 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1551358 no esta en reindex
# Item 1432697 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1551358 no esta en reindex
# Item 812655 no esta en reindex
# Item 625267 no esta en reindex
# Item 291823 no esta en reindex
# Item 636862 no esta en reindex
# Item 1271327 no esta en reindex
# Item 554715 no esta en reindex
# Item 1551358 no esta en reindex
# Item 1436780 no esta en reindex
# Item 457352 no esta en reindex
# Item 1714186 no esta en reindex
# Item 812655 no esta en reindex
# Item 363739 no esta en reindex
# Item 1580278 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 2039233 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 969044 no esta en reindex
# Item 1052414 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1179344 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1225034 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1656284 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1551358 no esta en reindex
# Item 636862 no esta en reindex
# Item 1830885 no esta en reindex
# Item 1047106 no esta en reindex
# Item 501869 no esta en reindex
# Item 812655 no esta en reindex
# Item 1540898 no esta en reindex
# Item 2088000 no esta en reindex
# Item 812655 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1271327 no esta en reindex
# Item 417263 no esta en reindex
# Item 126450 no esta en reindex
# Item 1847546 no esta en reindex
# Item 625267 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1039493 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1628486 no esta en reindex
# Item 625267 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1611218 no esta en reindex
# Item 1435934 no esta en reindex
# Item 1576423 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1742063 no esta en reindex
# Item 1289288 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 1997800 no esta en reindex
# Item 1047106 no esta en reindex
# Item 126450 no esta en reindex
# Item 666855 no esta en reindex
# Item 1927909 no esta en reindex
# Item 394894 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 241469 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1457355 no esta en reindex
# Item 363739 no esta en reindex
# Item 625267 no esta en reindex
# Item 1611218 no esta en reindex
# Item 550219 no esta en reindex
# Item 550219 no esta en reindex
# Item 363739 no esta en reindex
# Item 1613535 no esta en reindex
# Item 417263 no esta en reindex
# Item 194713 no esta en reindex
# Item 1435934 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1435934 no esta en reindex
# Item 363739 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 363739 no esta en reindex
# Item 304222 no esta en reindex
# Item 625267 no esta en reindex
# Item 1927909 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1927909 no esta en reindex
# Item 257545 no esta en reindex
# Item 666855 no esta en reindex
# Item 1714186 no esta en reindex
# Item 1449752 no esta en reindex
# Item 417263 no esta en reindex
# Item 417263 no esta en reindex
# Item 417263 no esta en reindex
# Item 304222 no esta en reindex
# Item 636862 no esta en reindex
# Item 2086215 no esta en reindex
# Item 837923 no esta en reindex
# Item 1611218 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1714186 no esta en reindex
# Item 1927909 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1986189 no esta en reindex
# Item 1054592 no esta en reindex
# Item 1659656 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 739932 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1289288 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1585554 no esta en reindex
# Item 837923 no esta en reindex
# Item 1742063 no esta en reindex
# Item 1455545 no esta en reindex
# Item 1570916 no esta en reindex
# Item 1732558 no esta en reindex
# Item 970250 no esta en reindex
# Item 2039233 no esta en reindex
# Item 382200 no esta en reindex
# Item 1457355 no esta en reindex
# Item 492003 no esta en reindex
# Item 1271327 no esta en reindex
# Item 2016223 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1853773 no esta en reindex
# Item 1611218 no esta en reindex
# Item 304222 no esta en reindex
# Item 1098759 no esta en reindex
# Item 235617 no esta en reindex
# Item 1592767 no esta en reindex
# Item 1478233 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1400041 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1047106 no esta en reindex
# Item 304222 no esta en reindex
# Item 1979324 no esta en reindex
# Item 2039233 no esta en reindex
# Item 194713 no esta en reindex
# Item 1276876 no esta en reindex
# Item 53589 no esta en reindex
# Item 566196 no esta en reindex
# Item 625267 no esta en reindex
# Item 417263 no esta en reindex
# Item 86924 no esta en reindex
# Item 403558 no esta en reindex
# Item 965793 no esta en reindex
# Item 915633 no esta en reindex
# Item 636862 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1979324 no esta en reindex
# Item 1449752 no esta en reindex
# Item 373235 no esta en reindex
# Item 837923 no esta en reindex
# Item 2086215 no esta en reindex
# Item 486037 no esta en reindex
# Item 613812 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1229027 no esta en reindex
# Item 1276876 no esta en reindex
# Item 812655 no esta en reindex
# Item 965793 no esta en reindex
# Item 402345 no esta en reindex
# Item 625267 no esta en reindex
# Item 1928468 no esta en reindex
# Item 304222 no esta en reindex
# Item 1465062 no esta en reindex
# Item 749818 no esta en reindex
# Item 27844 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 178889 no esta en reindex
# Item 666855 no esta en reindex
# Item 1457355 no esta en reindex
# Item 363739 no esta en reindex
# Item 2039233 no esta en reindex
# Item 743017 no esta en reindex
# Item 83796 no esta en reindex
# Item 417263 no esta en reindex
# Item 625267 no esta en reindex
# Item 970250 no esta en reindex
# Item 827401 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1457355 no esta en reindex
# Item 625267 no esta en reindex
# Item 1357149 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 464836 no esta en reindex
# Item 970250 no esta en reindex
# Item 1047106 no esta en reindex
# Item 946018 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 1986189 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1271327 no esta en reindex
# Item 1292683 no esta en reindex
# Item 812655 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1518569 no esta en reindex
# Item 812655 no esta en reindex
# Item 1628486 no esta en reindex
# Item 138241 no esta en reindex
# Item 1873574 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 1737016 no esta en reindex
# Item 1605567 no esta en reindex
# Item 1283781 no esta en reindex
# Item 53589 no esta en reindex
# Item 1256425 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1965999 no esta en reindex
# Item 709763 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1014248 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1701695 no esta en reindex
# Item 51447 no esta en reindex
# Item 1787599 no esta en reindex
# Item 1787599 no esta en reindex
# Item 2016223 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 417263 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1567809 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1358048 no esta en reindex
# Item 2049454 no esta en reindex
# Item 291823 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1271327 no esta en reindex
# Item 16746 no esta en reindex
# Item 1288546 no esta en reindex
# Item 985063 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1455545 no esta en reindex
# Item 1457355 no esta en reindex
# Item 502862 no esta en reindex
# Item 417263 no esta en reindex
# Item 417263 no esta en reindex
# Item 1289288 no esta en reindex
# Item 194713 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 1047106 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1611218 no esta en reindex
# Item 178889 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1307983 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2016223 no esta en reindex
# Item 1271327 no esta en reindex
# Item 417263 no esta en reindex
# Item 808888 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1611218 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1866882 no esta en reindex
# Item 1540898 no esta en reindex
# Item 178889 no esta en reindex
# Item 1271327 no esta en reindex
# Item 1179344 no esta en reindex
# Item 417263 no esta en reindex
# Item 162613 no esta en reindex
# Item 1361100 no esta en reindex
# Item 417263 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1047106 no esta en reindex
# Item 394894 no esta en reindex
# Item 1436780 no esta en reindex
# Item 684664 no esta en reindex
# Item 1732558 no esta en reindex
# Item 625267 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1986189 no esta en reindex
# Item 932580 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1457355 no esta en reindex
# Item 417263 no esta en reindex
# Item 194713 no esta en reindex
# Item 743017 no esta en reindex
# Item 1992410 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1927909 no esta en reindex
# Item 965793 no esta en reindex
# Item 743017 no esta en reindex
# Item 373235 no esta en reindex
# Item 1357149 no esta en reindex
# Item 1611218 no esta en reindex
# Item 1047106 no esta en reindex
# Item 417263 no esta en reindex
# Item 1449752 no esta en reindex
# Item 625267 no esta en reindex
# Item 2039233 no esta en reindex
# Item 134417 no esta en reindex
# Item 1707526 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 812655 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 726348 no esta en reindex
# Item 1551358 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1580278 no esta en reindex
# Item 288453 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 1787599 no esta en reindex
# Item 970250 no esta en reindex
# Item 1400041 no esta en reindex
# Item 812655 no esta en reindex
# Item 709763 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 932580 no esta en reindex
# Item 1787599 no esta en reindex
# Item 301701 no esta en reindex
# Item 636862 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 304222 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1367001 no esta en reindex
# Item 417263 no esta en reindex
# Item 263736 no esta en reindex
# Item 291823 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1551358 no esta en reindex
# Item 625267 no esta en reindex
# Item 403558 no esta en reindex
# Item 417263 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1585554 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1358048 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1611218 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 779911 no esta en reindex
# Item 1054592 no esta en reindex
# Item 666855 no esta en reindex
# Item 1701695 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 1271327 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1455545 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1492931 no esta en reindex
# Item 53589 no esta en reindex
# Item 194713 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1400041 no esta en reindex
# Item 53589 no esta en reindex
# Item 1732558 no esta en reindex
# Item 1117558 no esta en reindex
# Item 965793 no esta en reindex
# Item 417263 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1400041 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1576423 no esta en reindex
# Item 1732558 no esta en reindex
# Item 2086215 no esta en reindex
# Item 126450 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1435934 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 1436780 no esta en reindex
# Item 417263 no esta en reindex
# Item 417263 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1656284 no esta en reindex
# Item 1046403 no esta en reindex
# Item 812655 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1455366 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 709763 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1592767 no esta en reindex
# Item 636862 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1611218 no esta en reindex
# Item 2086215 no esta en reindex
# Item 625267 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1986189 no esta en reindex
# Item 546 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1800012 no esta en reindex
# Item 913199 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 739932 no esta en reindex
# Item 1358048 no esta en reindex
# Item 461665 no esta en reindex
# Item 457352 no esta en reindex
# Item 812655 no esta en reindex
# Item 812655 no esta en reindex
# Item 2039233 no esta en reindex
# Item 480556 no esta en reindex
# Item 730340 no esta en reindex
# Item 1276876 no esta en reindex
# Item 126450 no esta en reindex
# Item 1928468 no esta en reindex
# Item 970250 no esta en reindex
# Item 1659656 no esta en reindex
# Item 625267 no esta en reindex
# Item 1449752 no esta en reindex
# Item 363739 no esta en reindex
# Item 1979324 no esta en reindex
# Item 1632751 no esta en reindex
# Item 753345 no esta en reindex
# Item 1880969 no esta en reindex
# Item 492003 no esta en reindex
# Item 512644 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1435934 no esta en reindex
# Item 1556982 no esta en reindex
# Item 636862 no esta en reindex
# Item 625267 no esta en reindex
# Item 2039233 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 969044 no esta en reindex
# Item 666855 no esta en reindex
# Item 1094533 no esta en reindex
# Item 194713 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1903126 no esta en reindex
# Item 915201 no esta en reindex
# Item 1362387 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1518569 no esta en reindex
# Item 849140 no esta en reindex
# Item 915633 no esta en reindex
# Item 235617 no esta en reindex
# Item 1358048 no esta en reindex
# Item 812655 no esta en reindex
# Item 1632751 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1814344 no esta en reindex
# Item 186308 no esta en reindex
# Item 1789986 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1047106 no esta en reindex
# Item 812655 no esta en reindex
# Item 636862 no esta en reindex
# Item 1271327 no esta en reindex
# Item 178889 no esta en reindex
# Item 1656284 no esta en reindex
# Item 2039233 no esta en reindex
# Item 812655 no esta en reindex
# Item 625267 no esta en reindex
# Item 1117558 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1283781 no esta en reindex
# Item 1047485 no esta en reindex
# Item 636862 no esta en reindex
# Item 636862 no esta en reindex
# Item 625267 no esta en reindex
# Item 2086215 no esta en reindex
# Item 363739 no esta en reindex
# Item 417263 no esta en reindex
# Item 837923 no esta en reindex
# Item 1656284 no esta en reindex
# Item 636862 no esta en reindex
# Item 493812 no esta en reindex
# Item 1986189 no esta en reindex
# Item 417263 no esta en reindex
# Item 2086215 no esta en reindex
# Item 417263 no esta en reindex
# Item 1276876 no esta en reindex
# Item 291823 no esta en reindex
# Item 493812 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1289288 no esta en reindex
# Item 1054592 no esta en reindex
# Item 709763 no esta en reindex
# Item 2086215 no esta en reindex
# Item 178889 no esta en reindex
# Item 417263 no esta en reindex
# Item 17066 no esta en reindex
# Item 575465 no esta en reindex
# Item 403558 no esta en reindex
# Item 915201 no esta en reindex
# Item 1742063 no esta en reindex
# Item 457352 no esta en reindex
# Item 1047106 no esta en reindex
# Item 812655 no esta en reindex
# Item 1965999 no esta en reindex
# Item 363739 no esta en reindex
# Item 636862 no esta en reindex
# Item 2088000 no esta en reindex
# Item 625267 no esta en reindex
# Item 1283781 no esta en reindex
# Item 230235 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1276876 no esta en reindex
# Item 1449752 no esta en reindex
# Item 178889 no esta en reindex
# Item 1435934 no esta en reindex
# Item 1700725 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1927909 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1276876 no esta en reindex
# Item 812655 no esta en reindex
# Item 812655 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1161828 no esta en reindex
# Item 709763 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1570916 no esta en reindex
# Item 16746 no esta en reindex
# Item 947298 no esta en reindex
# Item 457352 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1289288 no esta en reindex
# Item 194713 no esta en reindex
# Item 1540898 no esta en reindex
# Item 403558 no esta en reindex
# Item 1683808 no esta en reindex
# Item 2086215 no esta en reindex
# Item 291823 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1358048 no esta en reindex
# Item 709763 no esta en reindex
# Item 163659 no esta en reindex
# Item 417263 no esta en reindex
# Item 625267 no esta en reindex
# Item 363739 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1079915 no esta en reindex
# Item 1656284 no esta en reindex
# Item 241469 no esta en reindex
# Item 2086215 no esta en reindex
# Item 969044 no esta en reindex
# Item 812655 no esta en reindex
# Item 230235 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1809789 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1235984 no esta en reindex
# Item 363739 no esta en reindex
# Item 1611218 no esta en reindex
# Item 1763931 no esta en reindex
# Item 644251 no esta en reindex
# Item 1092147 no esta en reindex
# Item 457352 no esta en reindex
# Item 969044 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1873574 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1165152 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1576423 no esta en reindex
# Item 709763 no esta en reindex
# Item 417263 no esta en reindex
# Item 1960218 no esta en reindex
# Item 1289288 no esta en reindex
# Item 969044 no esta en reindex
# Item 937373 no esta en reindex
# Item 1986189 no esta en reindex
# Item 16746 no esta en reindex
# Item 2039233 no esta en reindex
# Item 417263 no esta en reindex
# Item 417263 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2088000 no esta en reindex
# Item 2088000 no esta en reindex
# Item 969044 no esta en reindex
# Item 1927909 no esta en reindex
# Item 743017 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1707526 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1179344 no esta en reindex
# Item 417263 no esta en reindex
# Item 970250 no esta en reindex
# Item 1271491 no esta en reindex
# Item 1047106 no esta en reindex
# Item 869450 no esta en reindex
# Item 812655 no esta en reindex
# Item 320794 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1455545 no esta en reindex
# Item 911531 no esta en reindex
# Item 417263 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1271327 no esta en reindex
# Item 709763 no esta en reindex
# Item 1928468 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1866882 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1540898 no esta en reindex
# Item 730216 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1054592 no esta en reindex
# Item 1492931 no esta en reindex
# Item 1457355 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 417263 no esta en reindex
# Item 2086215 no esta en reindex
# Item 131996 no esta en reindex
# Item 829073 no esta en reindex
# Item 1271327 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 1218398 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1866882 no esta en reindex
# Item 1179344 no esta en reindex
# Item 126450 no esta en reindex
# Item 1449752 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 1576423 no esta en reindex
# Item 480556 no esta en reindex
# Item 417263 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1271327 no esta en reindex
# Item 831767 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 457352 no esta en reindex
# Item 1611218 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1800012 no esta en reindex
# Item 471764 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1628486 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1707526 no esta en reindex
# Item 1435934 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1218398 no esta en reindex
# Item 636862 no esta en reindex
# Item 932580 no esta en reindex
# Item 1967172 no esta en reindex
# Item 1047106 no esta en reindex
# Item 636862 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1592767 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1632751 no esta en reindex
# Item 304222 no esta en reindex
# Item 1853773 no esta en reindex
# Item 932580 no esta en reindex
# Item 417263 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 1094533 no esta en reindex
# Item 2088000 no esta en reindex
# Item 250810 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1492931 no esta en reindex
# Item 288453 no esta en reindex
# Item 53589 no esta en reindex
# Item 1799953 no esta en reindex
# Item 1611218 no esta en reindex
# Item 981472 no esta en reindex
# Item 1927909 no esta en reindex
# Item 636862 no esta en reindex
# Item 288453 no esta en reindex
# Item 812655 no esta en reindex
# Item 417263 no esta en reindex
# Item 636862 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 194713 no esta en reindex
# Item 625267 no esta en reindex
# Item 970250 no esta en reindex
# Item 1656284 no esta en reindex
# Item 1927909 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1714186 no esta en reindex
# Item 2086215 no esta en reindex
# Item 802999 no esta en reindex
# Item 1986189 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 1611218 no esta en reindex
# Item 1218398 no esta en reindex
# Item 16746 no esta en reindex
# Item 837923 no esta en reindex
# Item 1436780 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1435934 no esta en reindex
# Item 178889 no esta en reindex
# Item 837923 no esta en reindex
# Item 492003 no esta en reindex
# Item 1732558 no esta en reindex
# Item 753475 no esta en reindex
# Item 1570916 no esta en reindex
# Item 812655 no esta en reindex
# Item 1449752 no esta en reindex
# Item 417263 no esta en reindex
# Item 1592767 no esta en reindex
# Item 512644 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1276876 no esta en reindex
# Item 1449752 no esta en reindex
# Item 178889 no esta en reindex
# Item 126450 no esta en reindex
# Item 288453 no esta en reindex
# Item 235617 no esta en reindex
# Item 2086215 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 625267 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1928468 no esta en reindex
# Item 512644 no esta en reindex
# Item 1800012 no esta en reindex
# Item 502862 no esta en reindex
# Item 812655 no esta en reindex
# Item 48479 no esta en reindex
# Item 2086215 no esta en reindex
# Item 812655 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2086215 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 812655 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1873574 no esta en reindex
# Item 1800012 no esta en reindex
# Item 625267 no esta en reindex
# Item 1540898 no esta en reindex
# Item 947298 no esta en reindex
# Item 1585554 no esta en reindex
# Item 1687257 no esta en reindex
# Item 1337152 no esta en reindex
# Item 1800012 no esta en reindex
# Item 858225 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1455545 no esta en reindex
# Item 457352 no esta en reindex
# Item 1492931 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2086215 no esta en reindex
# Item 154147 no esta en reindex
# Item 1271327 no esta en reindex
# Item 492003 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1611218 no esta en reindex
# Item 2039233 no esta en reindex
# Item 712660 no esta en reindex
# Item 812655 no esta en reindex
# Item 441106 no esta en reindex
# Item 644251 no esta en reindex
# Item 704890 no esta en reindex
# Item 636862 no esta en reindex
# Item 753475 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 216850 no esta en reindex
# Item 932580 no esta en reindex
# Item 915633 no esta en reindex
# Item 666855 no esta en reindex
# Item 1518569 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1271327 no esta en reindex
# Item 492003 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 304222 no esta en reindex
# Item 1632751 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1732558 no esta en reindex
# Item 2088000 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1449752 no esta en reindex
# Item 525510 no esta en reindex
# Item 1701831 no esta en reindex
# Item 709763 no esta en reindex
# Item 1787599 no esta en reindex
# Item 1632751 no esta en reindex
# Item 913199 no esta en reindex
# Item 1047106 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1540898 no esta en reindex
# Item 753345 no esta en reindex
# Item 1047106 no esta en reindex
# Item 837923 no esta en reindex
# Item 1492931 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2041918 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1435934 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1473841 no esta en reindex
# Item 1659656 no esta en reindex
# Item 594755 no esta en reindex
# Item 105317 no esta en reindex
# Item 1748414 no esta en reindex
# Item 837923 no esta en reindex
# Item 2016223 no esta en reindex
# Item 1758 no esta en reindex
# Item 241469 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1436780 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 417263 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1179344 no esta en reindex
# Item 480556 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 625267 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1218398 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1276876 no esta en reindex
# Item 1054592 no esta en reindex
# Item 625267 no esta en reindex
# Item 1927909 no esta en reindex
# Item 2086215 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1518569 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1847546 no esta en reindex
# Item 417263 no esta en reindex
# Item 1965999 no esta en reindex
# Item 1251296 no esta en reindex
# Item 291823 no esta en reindex
# Item 843436 no esta en reindex
# Item 2086215 no esta en reindex
# Item 492003 no esta en reindex
# Item 1986189 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 965793 no esta en reindex
# Item 1656284 no esta en reindex
# Item 178889 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1580278 no esta en reindex
# Item 1276876 no esta en reindex
# Item 304222 no esta en reindex
# Item 1175243 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1361100 no esta en reindex
# Item 417263 no esta en reindex
# Item 969044 no esta en reindex
# Item 837923 no esta en reindex
# Item 1986189 no esta en reindex
# Item 915633 no esta en reindex
# Item 2088000 no esta en reindex
# Item 837923 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1271327 no esta en reindex
# Item 2039233 no esta en reindex
# Item 105317 no esta en reindex
# Item 538007 no esta en reindex
# Item 519359 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1540898 no esta en reindex
# Item 417263 no esta en reindex
# Item 644251 no esta en reindex
# Item 1701695 no esta en reindex
# Item 947298 no esta en reindex
# Item 363739 no esta en reindex
# Item 363739 no esta en reindex
# Item 1271327 no esta en reindex
# Item 709763 no esta en reindex
# Item 235791 no esta en reindex
# Item 1821520 no esta en reindex
# Item 2039233 no esta en reindex
# Item 291823 no esta en reindex
# Item 1457355 no esta en reindex
# Item 417263 no esta en reindex
# Item 636862 no esta en reindex
# Item 1927909 no esta en reindex
# Item 743017 no esta en reindex
# Item 1047106 no esta en reindex
# Item 812655 no esta en reindex
# Item 1492931 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 812655 no esta en reindex
# Item 666855 no esta en reindex
# Item 417263 no esta en reindex
# Item 1613535 no esta en reindex
# Item 288453 no esta en reindex
# Item 492003 no esta en reindex
# Item 1791354 no esta en reindex
# Item 403558 no esta en reindex
# Item 478414 no esta en reindex
# Item 1612484 no esta en reindex
# Item 512644 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1965999 no esta en reindex
# Item 1800012 no esta en reindex
# Item 625267 no esta en reindex
# Item 932580 no esta en reindex
# Item 1283781 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1455545 no esta en reindex
# Item 1551358 no esta en reindex
# Item 932580 no esta en reindex
# Item 2086215 no esta en reindex
# Item 915633 no esta en reindex
# Item 625267 no esta en reindex
# Item 2039233 no esta en reindex
# Item 965793 no esta en reindex
# Item 178889 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1492931 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1715493 no esta en reindex
# Item 812655 no esta en reindex
# Item 812655 no esta en reindex
# Item 1436780 no esta en reindex
# Item 2086215 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1179344 no esta en reindex
# Item 1457355 no esta en reindex
# Item 2086215 no esta en reindex
# Item 684664 no esta en reindex
# Item 363739 no esta en reindex
# Item 178889 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 178889 no esta en reindex
# Item 373235 no esta en reindex
# Item 1732558 no esta en reindex
# Item 1551358 no esta en reindex
# Item 820192 no esta en reindex
# Item 1289288 no esta en reindex
# Item 1442908 no esta en reindex
# Item 1873574 no esta en reindex
# Item 625267 no esta en reindex
# Item 417263 no esta en reindex
# Item 417263 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 788889 no esta en reindex
# Item 2086215 no esta en reindex
# Item 743017 no esta en reindex
# Item 970250 no esta en reindex
# Item 288453 no esta en reindex
# Item 95036 no esta en reindex
# Item 1518569 no esta en reindex
# Item 512644 no esta en reindex
# Item 636862 no esta en reindex
# Item 1054592 no esta en reindex
# Item 644251 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1707526 no esta en reindex
# Item 2039233 no esta en reindex
# Item 749818 no esta en reindex
# Item 812655 no esta en reindex
# Item 709763 no esta en reindex
# Item 1540898 no esta en reindex
# Item 417263 no esta en reindex
# Item 1436780 no esta en reindex
# Item 178889 no esta en reindex
# Item 934704 no esta en reindex
# Item 291823 no esta en reindex
# Item 1271327 no esta en reindex
# Item 291823 no esta en reindex
# Item 2086215 no esta en reindex
# Item 915633 no esta en reindex
# Item 1632751 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1576423 no esta en reindex
# Item 1641899 no esta en reindex
# Item 178889 no esta en reindex
# Item 1455545 no esta en reindex
# Item 1787599 no esta en reindex
# Item 194713 no esta en reindex
# Item 932580 no esta en reindex
# Item 741252 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1047106 no esta en reindex
# Item 89006 no esta en reindex
# Item 1982555 no esta en reindex
# Item 820192 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1540898 no esta en reindex
# Item 636862 no esta en reindex
# Item 749446 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1256425 no esta en reindex
# ...
# Item 53589 no esta en reindex
# Item 709763 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1283781 no esta en reindex
# Item 30470 no esta en reindex
# Item 417263 no esta en reindex
# Item 1094533 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1927909 no esta en reindex
# Item 550219 no esta en reindex
# Item 1436780 no esta en reindex
# Item 985142 no esta en reindex
# Item 1927909 no esta en reindex
# Item 2086215 no esta en reindex
# Item 969044 no esta en reindex
# Item 1928468 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1271327 no esta en reindex
# Item 666855 no esta en reindex
# Item 625267 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 1325928 no esta en reindex
# Item 1492931 no esta en reindex
# Item 1492931 no esta en reindex
# Item 1847546 no esta en reindex
# Item 2039233 no esta en reindex
# Item 965793 no esta en reindex
# Item 1732558 no esta en reindex
# Item 1518569 no esta en reindex
# Item 261612 no esta en reindex
# Item 2007408 no esta en reindex
# Item 1576423 no esta en reindex
# Item 1289288 no esta en reindex
# Item 1244047 no esta en reindex
# Item 815731 no esta en reindex
# Item 2086215 no esta en reindex
# Item 126450 no esta en reindex
# Item 625267 no esta en reindex
# Item 1449752 no esta en reindex
# Item 812655 no esta en reindex
# Item 2086215 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 363739 no esta en reindex
# Item 417263 no esta en reindex
# Item 1927909 no esta en reindex
# Item 417263 no esta en reindex
# Item 987081 no esta en reindex
# Item 1965999 no esta en reindex
# Item 1449752 no esta en reindex
# Item 915633 no esta en reindex
# Item 493812 no esta en reindex
# Item 1283781 no esta en reindex
# Item 1986189 no esta en reindex
# Item 666855 no esta en reindex
# Item 2088000 no esta en reindex
# Item 403558 no esta en reindex
# Item 1817457 no esta en reindex
# Item 304222 no esta en reindex
# Item 749818 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1117558 no esta en reindex
# Item 1986189 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 625267 no esta en reindex
# Item 2039233 no esta en reindex
# Item 625267 no esta en reindex
# Item 815212 no esta en reindex
# Item 1576423 no esta en reindex
# Item 304222 no esta en reindex
# Item 1853773 no esta en reindex
# Item 512644 no esta en reindex
# Item 1449752 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1873574 no esta en reindex
# Item 155134 no esta en reindex
# Item 235791 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1866882 no esta en reindex
# Item 1492931 no esta en reindex
# Item 1276876 no esta en reindex
# Item 2086215 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1800012 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 2050721 no esta en reindex
# Item 113374 no esta en reindex
# Item 1358048 no esta en reindex
# Item 550219 no esta en reindex
# Item 1707526 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1991021 no esta en reindex
# Item 1986189 no esta en reindex
# Item 1707526 no esta en reindex
# Item 126450 no esta en reindex
# Item 644251 no esta en reindex
# Item 53589 no esta en reindex
# Item 126450 no esta en reindex
# Item 562307 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1012196 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2016223 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1492931 no esta en reindex
# Item 457352 no esta en reindex
# Item 970250 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1818465 no esta en reindex
# Item 126450 no esta en reindex
# Item 1707526 no esta en reindex
# Item 2016223 no esta en reindex
# Item 554715 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1455545 no esta en reindex
# Item 947298 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1492931 no esta en reindex
# Item 1670816 no esta en reindex
# Item 1576423 no esta en reindex
# Item 812655 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1540898 no esta en reindex
# Item 726348 no esta en reindex
# Item 744292 no esta en reindex
# Item 1435934 no esta en reindex
# Item 2086215 no esta en reindex
# Item 666855 no esta en reindex
# Item 625267 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1628486 no esta en reindex
# Item 709763 no esta en reindex
# Item 53589 no esta en reindex
# Item 457352 no esta en reindex
# Item 1707526 no esta en reindex
# Item 636862 no esta en reindex
# Item 1714186 no esta en reindex
# Item 812655 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1928468 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1540898 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1047106 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1551358 no esta en reindex
# Item 403558 no esta en reindex
# Item 1551358 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1218398 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1276990 no esta en reindex
# Item 947298 no esta en reindex
# Item 2039233 no esta en reindex
# Item 480556 no esta en reindex
# Item 1275757 no esta en reindex
# Item 915633 no esta en reindex
# Item 1737016 no esta en reindex
# Item 1866882 no esta en reindex
# Item 625267 no esta en reindex
# Item 512644 no esta en reindex
# Item 194713 no esta en reindex
# Item 890472 no esta en reindex
# Item 1225475 no esta en reindex
# Item 1927909 no esta en reindex
# Item 2039233 no esta en reindex
# Item 235617 no esta en reindex
# Item 965793 no esta en reindex
# Item 178889 no esta en reindex
# Item 126450 no esta en reindex
# Item 970250 no esta en reindex
# Item 812013 no esta en reindex
# Item 1800012 no esta en reindex
# Item 1400041 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1580278 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 1518569 no esta en reindex
# Item 1054592 no esta en reindex
# Item 1358048 no esta en reindex
# Item 2086215 no esta en reindex
# Item 363739 no esta en reindex
# Item 1632751 no esta en reindex
# Item 912105 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 1435934 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1449752 no esta en reindex
# Item 417263 no esta en reindex
# Item 837923 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1047106 no esta en reindex
# Item 812655 no esta en reindex
# Item 1271327 no esta en reindex
# Item 1592767 no esta en reindex
# Item 304222 no esta en reindex
# Item 812655 no esta en reindex
# Item 1991021 no esta en reindex
# Item 636862 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1866882 no esta en reindex
# Item 636862 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1701695 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1545772 no esta en reindex
# Item 1627617 no esta en reindex
# Item 1449752 no esta en reindex
# Item 965793 no esta en reindex
# Item 709763 no esta en reindex
# Item 1400041 no esta en reindex
# Item 1965999 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 812655 no esta en reindex
# Item 2039233 no esta en reindex
# Item 666855 no esta en reindex
# Item 1540898 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1455545 no esta en reindex
# Item 2039233 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1787599 no esta en reindex
# Item 1986189 no esta en reindex
# Item 1570916 no esta en reindex
# Item 492003 no esta en reindex
# Item 1179344 no esta en reindex
# Item 2086215 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 1100438 no esta en reindex
# Item 2086215 no esta en reindex
# Item 363739 no esta en reindex
# Item 812655 no esta en reindex
# Item 625267 no esta en reindex
# Item 126450 no esta en reindex
# Item 550219 no esta en reindex
# Item 1305072 no esta en reindex
# Item 666855 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1761546 no esta en reindex
# Item 965793 no esta en reindex
# Item 1271327 no esta en reindex
# Item 1455545 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 417263 no esta en reindex
# Item 625267 no esta en reindex
# Item 417263 no esta en reindex
# Item 2086215 no esta en reindex
# Item 970623 no esta en reindex
# Item 753345 no esta en reindex
# Item 235617 no esta en reindex
# Item 1580278 no esta en reindex
# Item 820964 no esta en reindex
# Item 666855 no esta en reindex
# Item 1179344 no esta en reindex
# Item 23244 no esta en reindex
# Item 1744743 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 1047501 no esta en reindex
# Item 506575 no esta en reindex
# Item 1791625 no esta en reindex
# Item 965793 no esta en reindex
# Item 1570916 no esta en reindex
# Item 1455545 no esta en reindex
# Item 2039233 no esta en reindex
# Item 625267 no esta en reindex
# Item 932580 no esta en reindex
# Item 1358048 no esta en reindex
# Item 178889 no esta en reindex
# Item 2039233 no esta en reindex
# Item 317132 no esta en reindex
# Item 812655 no esta en reindex
# Item 1455545 no esta en reindex
# Item 1449752 no esta en reindex
# Item 417263 no esta en reindex
# Item 1576423 no esta en reindex
# Item 1628486 no esta en reindex
# Item 512644 no esta en reindex
# Item 178889 no esta en reindex
# Item 1047106 no esta en reindex
# Item 194713 no esta en reindex
# Item 1256425 no esta en reindex
# Item 1707526 no esta en reindex
# Item 512644 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1117558 no esta en reindex
# Item 709763 no esta en reindex
# Item 126450 no esta en reindex
# Item 666855 no esta en reindex
# Item 1602599 no esta en reindex
# Item 1866882 no esta en reindex
# Item 1996017 no esta en reindex
# Item 2088000 no esta en reindex
# Item 837923 no esta en reindex
# Item 53589 no esta en reindex
# Item 363739 no esta en reindex
# Item 1592767 no esta en reindex
# Item 1485269 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 1457355 no esta en reindex
# Item 194713 no esta en reindex
# Item 1256425 no esta en reindex
# Item 666855 no esta en reindex
# Item 837923 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1187801 no esta en reindex
# Item 636862 no esta en reindex
# Item 1173016 no esta en reindex
# Item 1484376 no esta en reindex
# Item 1732558 no esta en reindex
# Item 474469 no esta en reindex
# Item 1015498 no esta en reindex
# Item 2039233 no esta en reindex
# Item 812655 no esta en reindex
# Item 403558 no esta en reindex
# Item 1675114 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1628486 no esta en reindex
# Item 1449752 no esta en reindex
# Item 1540898 no esta en reindex
# Item 2002354 no esta en reindex
# Item 113374 no esta en reindex
# Item 1455545 no esta en reindex
# Item 417263 no esta en reindex
# Item 812655 no esta en reindex
# Item 1707526 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2086215 no esta en reindex
# Item 336614 no esta en reindex
# Item 598254 no esta en reindex
# Item 363739 no esta en reindex
# Item 812655 no esta en reindex
# Item 2016223 no esta en reindex
# Item 1830885 no esta en reindex
# Item 2073883 no esta en reindex
# Item 1435934 no esta en reindex
# Item 417263 no esta en reindex
# Item 1737016 no esta en reindex
# Item 1800012 no esta en reindex
# Item 970250 no esta en reindex
# Item 915201 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1251296 no esta en reindex
# Item 1551358 no esta en reindex
# Item 417263 no esta en reindex
# Item 1457355 no esta en reindex
# Item 363739 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1742063 no esta en reindex
# Item 1124621 no esta en reindex
# Item 912105 no esta en reindex
# Item 194713 no esta en reindex
# Item 1830885 no esta en reindex
# Item 1611218 no esta en reindex
# Item 1695885 no esta en reindex
# Item 625267 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1986189 no esta en reindex
# Item 843436 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1117558 no esta en reindex
# Item 749818 no esta en reindex
# Item 1873574 no esta en reindex
# Item 1947698 no esta en reindex
# Item 969044 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1117558 no esta en reindex
# Item 1130394 no esta en reindex
# Item 2088000 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1659656 no esta en reindex
# Item 1457355 no esta en reindex
# Item 1551358 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 932580 no esta en reindex
# Item 1283781 no esta en reindex
# Item 1117558 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 812655 no esta en reindex
# Item 1707526 no esta en reindex
# Item 636862 no esta en reindex
# Item 812655 no esta en reindex
# Item 291823 no esta en reindex
# Item 1193286 no esta en reindex
# Item 625267 no esta en reindex
# Item 2086215 no esta en reindex
# Item 13776 no esta en reindex
# Item 970250 no esta en reindex
# Item 812655 no esta en reindex
# Item 1436780 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1656284 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 1592767 no esta en reindex
# Item 911531 no esta en reindex
# Item 1019944 no esta en reindex
# Item 2086215 no esta en reindex
# Item 753345 no esta en reindex
# Item 1763931 no esta en reindex
# Item 1616313 no esta en reindex
# Item 625267 no esta en reindex
# Item 1787599 no esta en reindex
# Item 1707526 no esta en reindex
# Item 636862 no esta en reindex
# Item 1276876 no esta en reindex
# Item 2097301 no esta en reindex
# Item 625267 no esta en reindex
# Item 965793 no esta en reindex
# Item 2039233 no esta en reindex
# Item 2086215 no esta en reindex
# Item 413682 no esta en reindex
# Item 1047106 no esta en reindex
# Item 2086215 no esta en reindex
# Item 1714186 no esta en reindex
# Item 2039233 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex
# Item 1847546 no esta en reindex
# Item 1047106 no esta en reindex
# Item 1927909 no esta en reindex
# Item 126450 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1847546 no esta en reindex
# Item 2086215 no esta en reindex
# Item 837923 no esta en reindex
# Item 1551358 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1927909 no esta en reindex
# Item 1400041 no esta en reindex
# Item 837923 no esta en reindex
# Item 1136712 no esta en reindex
# Item 1325928 no esta en reindex
# Item 311399 no esta en reindex
# Item 730216 no esta en reindex
# Item 753345 no esta en reindex
# Item 1540898 no esta en reindex
# Item 53589 no esta en reindex
# Item 417263 no esta en reindex
# Item 2039233 no esta en reindex
# Item 235617 no esta en reindex
# Item 2088000 no esta en reindex
# Item 1436780 no esta en reindex
# Item 1094533 no esta en reindex
# Item 1449752 no esta en reindex
# Item 417263 no esta en reindex
# Item 1047106 no esta en reindex
# Item 837923 no esta en reindex
# Item 1271327 no esta en reindex
# Item 126450 no esta en reindex
# Item 1251296 no esta en reindex
# Item 304222 no esta en reindex
# Item 2039233 no esta en reindex
# Item 1927909 no esta en reindex
# Item 749818 no esta en reindex
# Item 216850 no esta en reindex
# Item 2002354 no esta en reindex
# Item 739932 no esta en reindex
# Item 1732558 no esta en reindex
# Item 178889 no esta en reindex
# Item 1656284 no esta en reindex
# Item 837923 no esta en reindex
# Item 970250 no esta en reindex
# Item 912105 no esta en reindex
# Item 373235 no esta en reindex
# Item 1309688 no esta en reindex

# %%
from google.colab import files

files.download(f'/content/SASRec.epoch={args.num_epochs}.lr={args.lr}.layer={args.num_blocks}.head={args.num_heads}.hidden={args.hidden_units}.maxlen={args.maxlen}.csv')

# %% [markdown]
# # Preparar dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gzip
from collections import defaultdict
from datetime import datetime

def kk():
  return -1
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield eval(l)

def create_dataset_train(path_input, path_output):
  # Crea un archivo .inter para usar con recbole
  reindex = defaultdict(kk)
  index = defaultdict(kk)
  with open(f"{path_output}.txt", 'w') as file:
    user_id = 1
    item_count = 1
    user = {}
    for l in tqdm(parse(path_input)):
      biggest_timestamp = 0
      history = []
      for event in l['user_history']:     
        if event['event_type'] == 'view':
          item_id = event['event_info']
          if reindex[item_id] == -1:
            reindex[item_id] = item_count
            index[item_count] = item_id
            item = item_count
            item_count += 1
          else:
            item = reindex[item_id]
          time = int(datetime.strptime(event['event_timestamp'], '%Y-%m-%dT%H:%M:%S.%f%z').timestamp())
          history.append((item, time))
          if time > biggest_timestamp:
            biggest_timestamp = time
      history.sort(key=lambda x: x[1])
      for x in history:
        file.write(' '.join([str(user_id), str(x[0])]) + '\n')
      if len(history) > 0:
        if reindex[l['item_bought']] == -1:
          reindex[l['item_bought']] = item_count
          index[item_count] = l['item_bought']
          item_count += 1
        file.write(' '.join([str(user_id), str(reindex[l['item_bought']])]) + '\n')
        user_id += 1
  return reindex, index, user_id, item_count

def add_test_dataset(path_input, path_dataset, reindex, index, last_user_id, last_item_id):
  """ 
  Esta funcion agrega los items del dataset de test al training. Solamente
  se agregan si es que son por lo menos 2 items en la secuencia, sino no tiene sentido
  """
  reindex = reindex.copy()
  index = index.copy()
  with open(f"{path_dataset}.txt", "a") as file:
    user_id = last_user_id
    item_count = last_item_id
    for l in tqdm(parse(path_input)):
      history = []
      for event in l['user_history']:
        if event['event_type'] == 'view':
          item_id = event['event_info']
          if reindex[item_id] == -1:
            reindex[item_id] = item_count
            index[item_count] = item_id
            item = item_count
            item_count += 1
          else:
            item = reindex[item_id]
          time = int(datetime.strptime(event['event_timestamp'], '%Y-%m-%dT%H:%M:%S.%f%z').timestamp())
          history.append((item, time))
      history.sort(key=lambda x: x[1])
      if len(history) > 1:
        for x in history:
          file.write(' '.join([str(user_id), str(x[0])]) + '\n')
        user_id += 1
    return reindex, index
def create_dataset_test(path_input, path_output, reindex):
  with open(f"{path_output}.txt", 'w') as file:
    user_id = 1
    item_count = 1
    user = {}
    for l in tqdm(parse(path_input)):
      history = []
      for event in l['user_history']:     
        if event['event_type'] == 'view' and reindex[event['event_info']] != -1:
          item = reindex[event['event_info']]
          """
          if reindex[item_id] == -1:
            reindex[item_id] = item_count
            index[item_count] = item_id
            item = item_count
            item_count += 1
            print(item_id)
          else:
            item = reindex[item_id]
          """
          time = int(datetime.strptime(event['event_timestamp'], '%Y-%m-%dT%H:%M:%S.%f%z').timestamp())
          history.append((item, time))
      history.sort(key=lambda x: x[1])
      for x in history:
        file.write(' '.join([str(user_id), str(x[0])]) + '\n')
      if len(history) == 0:
        item_id = 1
        file.write(' '.join([str(user_id), str(item_id)]) + '\n')
      user_id += 1
  return reindex

# %%
reindex_train, index_train, user_id, item_count = create_dataset_train('/content/drive/Shareddrives/RecSys/Datasets/train_dataset.jl.gz', 'mercadolibre')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
final_reindex, final_index = add_test_dataset('/content/drive/Shareddrives/RecSys/Datasets/test_dataset.jl.gz', 'mercadolibre', reindex_train, index_train, user_id, item_count)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
reindex_test = create_dataset_test('/content/drive/Shareddrives/RecSys/Datasets/test_dataset.jl.gz', 'mercadolibre_test', final_reindex)
# Out:
# 177070it [01:30, 1963.57it/s]

# %%
item_count
# Out:
# 1605251

# %%
itemnum
# Out:
# 2101271

# %%
import pickle

# %%
with open('reindex.pkl', 'wb') as f:
  pickle.dump(final_reindex, f)

# %%
with open('index.pkl', 'wb') as f:
  pickle.dump(final_index, f)

# %%
with open('/content/drive/Shareddrives/RecSys/MeLi/reindex.pkl', 'rb') as f:
  final_reindex = pickle.load(f)

with open('/content/drive/Shareddrives/RecSys/MeLi/index.pkl', 'rb') as f:
  final_index = pickle.load(f)

# %%
def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1

# %%
file_len('/content/drive/Shareddrives/RecSys/MeLi/results/SASRec.epoch=50.lr=0.001.layer=3.head=1.hidden=64.maxlen=30.csv')
# Out:
# 177070
